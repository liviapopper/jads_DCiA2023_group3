# %% [markdown]
# # Topic modelling process with example
#
# ### 1. Topic modelling:
#     1. Topic modelling structure
#     2. Get value from you model

# %%
#Imports
import pandas as pd
import numpy as np
import json, string, pprint, spacy, nltk, math, gensim
import gensim.corpora as corpora
import nl_core_news_lg 
from gensim.utils import simple_preprocess
from bertopic import BERTopic
from nltk.corpus import stopwords
from sentence_transformers import SentenceTransformer, util
from bertopic.backend import languages 
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
from nltk.tokenize import sent_tokenize
from typing import List
from hdbscan import HDBSCAN
from umap import UMAP
import plotly.io as pio
pio.renderers.default='iframe'

# %% [markdown]
# ### 1.1. Topic modelling structure

# %%
# import previously processed data
paragraphsDF = pd.read_csv('actors_organizations_processed_data.csv')
paragraphsDF
# Out:
#                                                     title  paragraph_num  \
# 0       Contaminatie in het vlees van ‘grote grazers’ ...              1
# 1       Contaminatie in het vlees van ‘grote grazers’ ...              2
# 2       Contaminatie in het vlees van ‘grote grazers’ ...              3
# 3       Contaminatie in het vlees van ‘grote grazers’ ...              4
# 4       Contaminatie in het vlees van ‘grote grazers’ ...              5
# ...                                                   ...            ...
# 223587  Verslag Landbouw- en Visserijraad 17 januari 2022             43
# 223588  Verslag Landbouw- en Visserijraad 17 januari 2022             44
# 223589  Verslag Landbouw- en Visserijraad 17 januari 2022             45
# 223590  Verslag Landbouw- en Visserijraad 17 januari 2022             46
# 223591  Verslag Landbouw- en Visserijraad 17 januari 2022             47
#
#                                            paragraph_text  \
# 0                                                       >
# 1                                     Retouradres Postbus
# 2                                  20350 2500 EJ Den Haag
# 3       De Voorzitter van de Tweede Kamer der Staten-G...
# 4                                                 Postbus
# ...                                                   ...
# 223587                                        1 Kamerstuk
# 223588                                    21 501-32, nr.
# 223589                                              1354.
# 223590  , was de Nederlandse inzet voor zeebaars om ee...
# 223591  De Minister van Landbouw, Natuur en Voedselkwa...
#
#        organizations_in_paragraph actors_in_paragraph       date_published  \
# 0                              []                  []  2022-12-14 00:00:00
# 1                              []                  []  2022-12-14 00:00:00
# 2                              []                  []  2022-12-14 00:00:00
# 3                              []                  []  2022-12-14 00:00:00
# 4                              []                  []  2022-12-14 00:00:00
# ...                           ...                 ...                  ...
# 223587                         []                  []  2022-01-26 00:00:00
# 223588                         []                  []  2022-01-26 00:00:00
# 223589                         []                  []  2022-01-26 00:00:00
# 223590                         []                  []  2022-01-26 00:00:00
# 223591                         []      ['Staghouwer']  2022-01-26 00:00:00
#
#        organizations_list one_or_more_organizations  \
# 0                    ['']                       NaN
# 1                    ['']                       NaN
# 2                    ['']                       NaN
# 3                    ['']                       NaN
# 4                    ['']                       NaN
# ...                   ...                       ...
# 223587               ['']                       NaN
# 223588               ['']                       NaN
# 223589               ['']                       NaN
# 223590               ['']                       NaN
# 223591               ['']                       NaN
#
#         numb_unique_organizations     actors_list one_or_more_actors  \
# 0                               1            ['']                NaN
# 1                               1            ['']                NaN
# 2                               1            ['']                NaN
# 3                               1            ['']                NaN
# 4                               1            ['']                NaN
# ...                           ...             ...                ...
# 223587                          1            ['']                NaN
# 223588                          1            ['']                NaN
# 223589                          1            ['']                NaN
# 223590                          1            ['']                NaN
# 223591                          1  ['Staghouwer']               True
#
#         numb_unique_actors  both_org_act
# 0                        1         False
# 1                        1         False
# 2                        1         False
# 3                        1         False
# 4                        1         False
# ...                    ...           ...
# 223587                   1         False
# 223588                   1         False
# 223589                   1         False
# 223590                   1         False
# 223591                   1         False
#
# [223592 rows x 13 columns]

# %% [markdown]
# Text preprocessing
# The preprocessing pipeline is mentioned below.
# ###### Tokenisation
# First basic tokenization is implemented, to split the text into
# tokens as is recommended by Kannan et al. (2014). For this process I used genism’s
# simple_preprocess, which will convert the text into lowercase & tokens and remove punctuation.

# %%
# Tokenization using gensim
def sent_to_words(sentences, deacc=True): # deacc=True removes punctuations
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence)))  
        
# Convert the data to a list
data = paragraphsDF["paragraph_text"].values.tolist()
data_words = list(sent_to_words(data))

# %% [markdown]
# ###### Stop word removal
# Secondly stop words will be removed from the data as well as a list of punctuation characters from
# the string.punctiation string, which is a pre-initialized string used as a string constant. These are
# removed because they have little relevance for understanding the content of a text (Kannan et al.,
# 2014).

# %%
# string.punctuation refers to a list of punctuations
stop_words = stopwords.words('dutch') + list(string.punctuation) #occur in many documents and have no link to a distinct industry.
additional_stop_words = ['geer','minister', 'postbus', 'retouradres','kamer', 'antwoord', 'www', 'brief', 'voorzitter', 'generaal', 'rijksoverheid', 'voorzitter', 'kamervrag', 'kamervraag','voorzitter', 'generaal', 'annoteren', 'agenda', 'kamerstuk', 'beantwoording', 'stichting','lid', 'partij', 'fractie', 'waarom', 'https', 'brief', 'verslag', 'motie', 'agendapunt', 'indiener', 'Tweede','tweede', 'Kenmerk', 'kenmerk', 'voortgang','kamerstukk', 'website', 'org', 'kamerbrief', 'idem', 'bijlage', 'wet', 'artikel', 'vergaderjaar', 'overheid', 'vraag', 'bericht', 'rapport', 'aanhangsel','staan', 'beleidsreactie','inhoudsopgave','lid', 'jaar', 'commissie', 'reactie', 'reactie', 'mededeling', 'http','zien', 'Elzijn', 'isie', 'ieren', 'pa', 'ibidem','programma','algemeen', 'pagina', 'context', 'circulair', 'voorbeeld', 'bijlaag', 'hoofdstuk', 'zien', 'leeswijzer', 'algemeen', 'blad', 'vooronderzoek', 'revisie', 'zone', 'legenda', 'lineair', 'stof', 'kolomn', 'tabel', 'zone', 'voorstellen', 'heer', 'dank', 'mevrouw', 'wel', 'tijd', 'meneer','adema', 'zaak', 'besluit','commisiedebat','datum', 'onderzoek', 'pagina','geer','minister','vraag','heer','kabinet','agenta','gemeente','gaan','kamer','wel','www', 'aanwezig', 'bijvoorbeeld', 'beide', 'dergelijke', 'dezelfde', 'elke', 'enkele', 'eveneens', 'gaande', 'gaandeweg', 'gehele', 'gehouden', 'genoeg', 'geweest', 'groter', 'hebben', 'heel', 'hetzelfde', 'hetzij', 'huidige', 'hunne', 'immers', 'inmiddels', 'intussen', 'juist', 'kleine', 'komt', 'korte', 'laatst', 'laten', 'lijken', 'maken', 'meeste', 'meestal', 'mede', 'middel', 'misschien', 'namelijk', 'nemen', 'net', 'nieuwe', 'niemand', 'niets', 'nodig', 'nogal', 'normaal', 'nu', 'o.a.', 'ofwel', 'omtrent', 'ondanks', 'onder andere', 'ongeveer', 'ons', 'onzes', 'onzeker', 'overal', 'precies', 'redelijk', 'sinds', 'slechts', 'sommige', 'steeds', 'terwijl', 'toch', 'totaal', 'uiteraard', 'vaak', 'vanaf', 'verschillende', 'vervolgens', 'volledig', 'volgens', 'vroeg', 'vroeger', 'waaronder', 'waarvan', 'wat betreft', 'weer', 'weinig', 'weliswaar', 'waarom', 'wanneer', 'zoals', 'zoveel', 'zulke', 'biodiversiteit', 'natuur', 'ecologie', 'soort', 'soorten', 'plant', 'planten', 'dier', 'dieren', 'bos', 'bosgebied', 'natuurgebied', 'bescherming', 'milieu', 'vervuiling', 'klimaatverandering', 'duurzaamheid', 'ecosysteem', 'biologisch', 'natuurlijk', 'gezondheid', 'beschermen', 'behoud', 'natuurbeheer', 'landschap', 'landschapsbeheer', 'fauna', 'flora', 'wetlands', 'bodem', 'water', 'lucht', 'biodiversiteitsverdrag', 'conventiebiologie', 'duurzaamheidsdoelen', 'habitats', 'inheems', 'soortenrijkdom', 'natuurlijke hulpbronnen', 'sustainable', 'sustainability']
stop_words_final = stop_words + additional_stop_words

# %%
# Removing the stopwords from the data
def rem_stopwords (text):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words_final] for doc in text]

# remove stop words
data_words_nostops = rem_stopwords(data_words)

# %% [markdown]
# ###### Lemmatization
# Lastly lemmatization has been performed, since its superior to stemming (Khyani et al., 2021),
# which is a text normalization technique that will switch any word to its lemma. For this process I
# used to open-source software library called spaCy, but NLTK could also have been used. The spaCy
# pre-trained model called en_core_web_md, can be thought of as some kind of pipeline. When this
# model is called upon a text or word, the text will run through the pipeline. If the text isn’t tokenized
# it will be tokenized after which different components will be activated. The thing that’s most
# interesting about this pipeline is a tagger which will assign Part-of-Speech tags based on spaCy’s
# English language model. This is done to gain a variety of annotations. The POS tag refers to a label
# which will be assigned to every token in the corpus to indicate the type of said token (is it a verb or
# punctation or adjective) and other grammatical categories. These POS tags can then be used in the
# preprocess to remove unwanted tags. The only tags that I have allowed in my analysis are Noun, Adj,
# Verb and Adv.

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out
# or even higher

nlp = spacy.load('nl_core_news_lg', disable=['parser', 'ner'])
nlp.max_length = 1322782
data_lemmatized = lemmatization(data_words_nostops, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
paragraphsDF['content'] = data_lemmatized
newDF = paragraphsDF.drop(paragraphsDF[paragraphsDF['content'].apply(lambda x: len(x)==0)].index)

# %% [markdown]
#  **Creating Corpus & BERTopics**
#
#
# BERTopic is a smart topic modeling algorithm that utilizes BERT (Bidirectional Encoder Representations from Transformers), a state-of-the-art natural language processing model developed by Google, to create meaningful and accurate topics from a given corpus. Here are some reasons why BERTopic is considered smart to use:
#
# 1. Incorporates contextual understanding: BERT is designed to understand the context of text data, which allows BERTopic to create topics that are based on the full context of the documents. This makes it more accurate and meaningful compared to other topic modeling algorithms.
#
# 2. Utilizes clustering: BERTopic uses clustering algorithms, such as Hierarchical Density-Based Spatial Clustering of Applications with Noise (HDBSCAN), to group similar documents together and create coherent topics. This clustering approach helps ensure that the topics are not only meaningful but also distinguishable from one another.
#
# 3. Customizable: BERTopic is highly customizable and can be tailored to specific needs. For example, users can adjust the number of topics they want to extract, or exclude specific words from the analysis to improve the quality of topics generated.
#
# 4. Efficient: BERTopic is designed to be computationally efficient and can process large datasets quickly. It also has the ability to update topics as new documents are added to the corpus, making it a scalable solution for topic modeling.
#
# 5. Easy to use: BERTopic is user-friendly and can be implemented with just a few lines of code. The resulting topics can be visualized using a variety of tools, making it easy to interpret and communicate the findings to others.
#
# Overall, BERTopic is a smart choice for topic modeling as it combines the power of BERT with efficient clustering algorithms and customizability to create meaningful and accurate topics from text data.
#
# We select the "dutch" as the main language for our documents. If you want a multilingual model that supports 50+ languages, please select "multilingual" instead.

# %%
newDF['corp'] = [','.join(map(str, l)) for l in newDF['content']]
newDF['corp'] = newDF['corp'].str.replace(',',' ', regex=False)

# %%
# reset the index of the dataframe
newDF = newDF.reset_index(drop=True)
newDF
# Out:
#                                                     title  paragraph_num  \
# 0       Contaminatie in het vlees van ‘grote grazers’ ...              4
# 1       Contaminatie in het vlees van ‘grote grazers’ ...              7
# 2       Contaminatie in het vlees van ‘grote grazers’ ...             13
# 3       Contaminatie in het vlees van ‘grote grazers’ ...             15
# 4       Contaminatie in het vlees van ‘grote grazers’ ...             17
# ...                                                   ...            ...
# 153461  Verslag Landbouw- en Visserijraad 17 januari 2022             40
# 153462  Verslag Landbouw- en Visserijraad 17 januari 2022             41
# 153463  Verslag Landbouw- en Visserijraad 17 januari 2022             42
# 153464  Verslag Landbouw- en Visserijraad 17 januari 2022             46
# 153465  Verslag Landbouw- en Visserijraad 17 januari 2022             47
#
#                                            paragraph_text  \
# 0       De Voorzitter van de Tweede Kamer der Staten-G...
# 1                                      : Parnassusplein 5
# 2       Correspondentie uitsluitend richten aan het re...
# 3       Betreft Contaminatie in het vlees van ‘grote g...
# 4       Geachte voorzitter, Ten behoeve van natuurbehe...
# ...                                                   ...
# 153461  zeebaars, tong, roggen, tarbot en griet, zeedu...
# 153462  Voor de bestanden van tong in de Noordzee (–28...
# 153463                          Zoals aan uw Kamer gemeld
# 153464  , was de Nederlandse inzet voor zeebaars om ee...
# 153465  De Minister van Landbouw, Natuur en Voedselkwa...
#
#        organizations_in_paragraph actors_in_paragraph       date_published  \
# 0                              []                  []  2022-12-14 00:00:00
# 1                              []                  []  2022-12-14 00:00:00
# 2                              []                  []  2022-12-14 00:00:00
# 3                              []                  []  2022-12-14 00:00:00
# 4                              []                  []  2022-12-14 00:00:00
# ...                           ...                 ...                  ...
# 153461                         []                  []  2022-01-26 00:00:00
# 153462                         []                  []  2022-01-26 00:00:00
# 153463                         []                  []  2022-01-26 00:00:00
# 153464                         []                  []  2022-01-26 00:00:00
# 153465                         []      ['Staghouwer']  2022-01-26 00:00:00
#
#        organizations_list one_or_more_organizations  \
# 0                    ['']                       NaN
# 1                    ['']                       NaN
# 2                    ['']                       NaN
# 3                    ['']                       NaN
# 4                    ['']                       NaN
# ...                   ...                       ...
# 153461               ['']                       NaN
# 153462               ['']                       NaN
# 153463               ['']                       NaN
# 153464               ['']                       NaN
# 153465               ['']                       NaN
#
#         numb_unique_organizations     actors_list one_or_more_actors  \
# 0                               1            ['']                NaN
# 1                               1            ['']                NaN
# 2                               1            ['']                NaN
# 3                               1            ['']                NaN
# 4                               1            ['']                NaN
# ...                           ...             ...                ...
# 153461                          1            ['']                NaN
# 153462                          1            ['']                NaN
# 153463                          1            ['']                NaN
# 153464                          1            ['']                NaN
# 153465                          1  ['Staghouwer']               True
#
#         numb_unique_actors  both_org_act  \
# 0                        1         False
# 1                        1         False
# 2                        1         False
# 3                        1         False
# 4                        1         False
# ...                    ...           ...
# 153461                   1         False
# 153462                   1         False
# 153463                   1         False
# 153464                   1         False
# 153465                   1         False
#
#                                                   content  \
# 0                                                 [staat]
# 1                                        [parnassusplein]
# 2       [correspondentie, uitsluitend, richten, vermel...
# 3       [betreffen, contaminatie, vlees, groot, grazer...
# 4       [geacht, behoeve, uiterwaarde, specifiek, robu...
# ...                                                   ...
# 153461  [zeebaars, tong, rogg, tarbot, griet, horsmakr...
# 153462  [bestand, tong, tarbot, griet, langoustine, ze...
# 153463                                           [melden]
# 153464  [Nederlands, inzet, toename, realiseren, klein...
# 153465                             [landbouw, staghouwer]
#
#                                                      corp
# 0                                                   staat
# 1                                          parnassusplein
# 2          correspondentie uitsluitend richten vermelding
# 3       betreffen contaminatie vlees groot grazer uite...
# 4       geacht behoeve uiterwaarde specifiek robuust r...
# ...                                                   ...
# 153461  zeebaars tong rogg tarbot griet horsmakreel la...
# 153462  bestand tong tarbot griet langoustine zeeduive...
# 153463                                             melden
# 153464  Nederlands inzet toename realiseren kleinschal...
# 153465                                landbouw staghouwer
#
# [153466 rows x 15 columns]

# %% [markdown]
# We can save the df for further inspection:

# %%
newDF.to_csv('actors_organizations_corp_data.csv', index=False)

# %% [markdown]
# You can load the processed dataset directly from here:

# %%
#newDF = pd.read_csv('actors_organizations_corp_data.csv')

# %%
# drop duplicated paragraphs
newDF = newDF.drop_duplicates(subset=['paragraph_text'])

# %%
newDF = newDF.reset_index(drop=True)
newDF
# Out:
#                                                    title  paragraph_num  \
# 0      Contaminatie in het vlees van ‘grote grazers’ ...              4
# 1      Contaminatie in het vlees van ‘grote grazers’ ...              7
# 2      Contaminatie in het vlees van ‘grote grazers’ ...             13
# 3      Contaminatie in het vlees van ‘grote grazers’ ...             15
# 4      Contaminatie in het vlees van ‘grote grazers’ ...             17
# ...                                                  ...            ...
# 83947  Verslag Landbouw- en Visserijraad 17 januari 2022             31
# 83948  Verslag Landbouw- en Visserijraad 17 januari 2022             34
# 83949  Verslag Landbouw- en Visserijraad 17 januari 2022             39
# 83950  Verslag Landbouw- en Visserijraad 17 januari 2022             42
# 83951  Verslag Landbouw- en Visserijraad 17 januari 2022             46
#
#                                           paragraph_text  \
# 0      De Voorzitter van de Tweede Kamer der Staten-G...
# 1                                     : Parnassusplein 5
# 2      Correspondentie uitsluitend richten aan het re...
# 3      Betreft Contaminatie in het vlees van ‘grote g...
# 4      Geachte voorzitter, Ten behoeve van natuurbehe...
# ...                                                  ...
# 83947  Visserijraad van 17 januari 2022.\nOp 1 januar...
# 83948  Op 7 februari a.s. organiseert het Franse voor...
# 83949  Visserijraad van december jl. is uw Kamer geïn...
# 83950                          Zoals aan uw Kamer gemeld
# 83951  , was de Nederlandse inzet voor zeebaars om ee...
#
#       organizations_in_paragraph actors_in_paragraph       date_published  \
# 0                             []                  []  2022-12-14 00:00:00
# 1                             []                  []  2022-12-14 00:00:00
# 2                             []                  []  2022-12-14 00:00:00
# 3                             []                  []  2022-12-14 00:00:00
# 4                             []                  []  2022-12-14 00:00:00
# ...                          ...                 ...                  ...
# 83947                         []                  []  2022-01-26 00:00:00
# 83948                         []                  []  2022-01-26 00:00:00
# 83949                         []                  []  2022-01-26 00:00:00
# 83950                         []                  []  2022-01-26 00:00:00
# 83951                         []                  []  2022-01-26 00:00:00
#
#       organizations_list one_or_more_organizations  numb_unique_organizations  \
# 0                   ['']                       NaN                          1
# 1                   ['']                       NaN                          1
# 2                   ['']                       NaN                          1
# 3                   ['']                       NaN                          1
# 4                   ['']                       NaN                          1
# ...                  ...                       ...                        ...
# 83947               ['']                       NaN                          1
# 83948               ['']                       NaN                          1
# 83949               ['']                       NaN                          1
# 83950               ['']                       NaN                          1
# 83951               ['']                       NaN                          1
#
#       actors_list one_or_more_actors  numb_unique_actors  both_org_act  \
# 0            ['']                NaN                   1         False
# 1            ['']                NaN                   1         False
# 2            ['']                NaN                   1         False
# 3            ['']                NaN                   1         False
# 4            ['']                NaN                   1         False
# ...           ...                ...                 ...           ...
# 83947        ['']                NaN                   1         False
# 83948        ['']                NaN                   1         False
# 83949        ['']                NaN                   1         False
# 83950        ['']                NaN                   1         False
# 83951        ['']                NaN                   1         False
#
#                                                  content  \
# 0                                                [staat]
# 1                                       [parnassusplein]
# 2      [correspondentie, uitsluitend, richten, vermel...
# 3      [betreffen, contaminatie, vlees, groot, grazer...
# 4      [geacht, behoeve, uiterwaarde, specifiek, robu...
# ...                                                  ...
# 83947  [visserijraad, nemen, Frankrijk, voorzittersch...
# 83948  [organiseren, Frans, voorzitterschap, informee...
# 83949  [visserijraad, jl, ïnformeren, akkoord, vereni...
# 83950                                           [melden]
# 83951  [Nederlands, inzet, toename, realiseren, klein...
#
#                                                     corp
# 0                                                  staat
# 1                                         parnassusplein
# 2         correspondentie uitsluitend richten vermelding
# 3      betreffen contaminatie vlees groot grazer uite...
# 4      geacht behoeve uiterwaarde specifiek robuust r...
# ...                                                  ...
# 83947  visserijraad nemen Frankrijk voorzitterschap r...
# 83948  organiseren Frans voorzitterschap informeel la...
# 83949  visserijraad jl ïnformeren akkoord verenigen k...
# 83950                                             melden
# 83951  Nederlands inzet toename realiseren kleinschal...
#
# [83952 rows x 15 columns]

# %% [markdown]
# ###### Transformer embedding
# BERTopic supports several libraries for encoding our text to dense vector embeddings. If we build poor quality embeddings, nothing we do in the other steps will be able to help us, so it is very important that we choose a suitable embedding model. the Sentence Transformers library provides the most extensive library of high-performing sentence embedding models.They can be found on HuggingFace Hub by searching for “sentence-transformers”. The first result of this search is sentence-transformers/all-MiniLM-L6-v2, this is a popular high-performing model that creates 384-dimensional sentence embeddings.

# %%
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')

# %% [markdown]
# ###### UMAP
# UMAP is an amazing technique for dimensionality reduction. In BERTopic, it is used to reduce the dimensionality of document embedding into something easier to use with HDBSCAN to create good clusters.
#
# However, it does has a significant number of parameters you could take into account. As exposing all parameters in BERTopic would be difficult to manage, we can instantiate our UMAP model and pass it to BERTopic:
#
# - n_neighbors is the number of neighboring sample points used when making the manifold approximation.By increasing n_neighbors we can preserve more global structures, whereas a lower n_neighbors better preserves local structures, finding a good n_neighbours value allows us to preserve both local and global structures relatively well.
# - n_components refers to the dimensionality of the embeddings after reducing them. A too low dimensionality (n_components) results in a loss of information while a too high dimensionality results in poorer clustering results.
# - metric refers to the method used to compute the distances in high dimensional space.
# - low_memory is used when datasets may consume a lot of memory.

# %%
umap_model = UMAP(n_neighbors=15, 
                  n_components=5, 
                  metric='cosine', 
                  low_memory=False)

# %% [markdown]
# ###### HDBSCAN
# After reducing the embeddings with UMAP, we use HDBSCAN to cluster our documents into clusters of similar documents. Similar to UMAP, HDBSCAN has many parameters that could be tweaked to improve the cluster's quality.
# - Min_cluster_size is arguably the most important parameter in HDBSCAN. It controls the minimum size of a cluster and thereby the number of clusters that will be generated.
# - Metric, like with HDBSCAN is used to calculate the distances.
# - Prediction_data, make sure you always set this value to True as it is needed to predict new points later on.

# %%
hdbscan_model = HDBSCAN(min_cluster_size=120, # 100
                        metric='euclidean', 
                        prediction_data=True,
                        min_samples=10)

# %% [markdown]
# ###### BERTopic model
# - The language parameter is used to simplify the selection of models for those who are not familiar with sentence-transformers models.
# - Top_n_words refers to the number of words per topic that you want to be extracted.
# - The n_gram_range parameter refers to the CountVectorizer used when creating the topic representation.
# - min_topic_size is an important parameter! It is used to specify what the minimum size of a topic can be.
# - nr_topics can be a tricky parameter. It specifies, after training the topic model, the number of topics that will be reduced.

# %%
model = BERTopic(language="dutch",
                 nr_topics="auto",
                 top_n_words = 10, 
                 n_gram_range = (1,1), #unigrams
                 umap_model=umap_model,
                 hdbscan_model=hdbscan_model,
                 embedding_model = embedding_model)
topics, probs = model.fit_transform(newDF['corp'])
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %% [markdown]
# We can then extract the most and least frequent topics:

# %%
model.get_topic_freq()
#44548 outliers
# Out:
#     Topic  Count
# 0      -1  41941
# 1       0  28043
# 2       1   1152
# 3       2    648
# 4       3    609
# 5       4    558
# 6       5    511
# 7       6    497
# 8       7    436
# 9       8    432
# 10      9    429
# 11     10    412
# 12     11    386
# 13     12    385
# 14     13    357
# 15     14    310
# 16     15    301
# 17     16    296
# 18     17    292
# 19     18    288
# 20     19    284
# 21     20    284
# 22     21    261
# 23     22    257
# 24     23    247
# 25     24    205
# 26     25    188
# 27     26    186
# 28     27    184
# 29     28    183
# 30     29    177
# 31     30    176
# 32     31    174
# 33     32    170
# 34     33    170
# 35     34    168
# 36     35    167
# 37     36    166
# 38     37    165
# 39     38    160
# 40     39    156
# 41     40    154
# 42     41    153
# 43     42    152
# 44     43    149
# 45     44    145
# 46     45    145
# 47     46    136
# 48     47    132
# 49     48    131
# 50     49    124
# 51     50    120

# %%
model.get_topic(6)
# Out:
# [('plan', 0.09133204304512553),
#  ('project', 0.06809770564792807),
#  ('planning', 0.03558821280534266),
#  ('komen', 0.01308824301289012),
#  ('geven', 0.012001880566448768),
#  ('aanpak', 0.01153848485143551),
#  ('groen', 0.010917154586908846),
#  ('waar', 0.010838567862203724),
#  ('gaan', 0.00972023207260067),
#  ('ambitie', 0.009693827887137867)]

# %% [markdown]
# ###### **Visualize Topics**
# After having trained our `BERTopic` model, we can iteratively go through perhaps a hundred topic to get a good
# understanding of the topics that were extract. However, that takes quite some time and lacks a global representation.
# Instead, we can visualize the topics that were generated in a way very similar to
# [LDAvis](https://github.com/cpsievert/LDAvis):

# %%
model.visualize_topics()
# Out:
# <iframe
#     scrolling="no"
#     width="670px"
#     height="670"
#     src="iframe_figures/figure_22.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
model.save("model_nneighbors15_ncomponents5_cluster_size120_unigram")
# Out:
# /home/didi/anaconda3/envs/nlp/lib/python3.9/site-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.

# %% [markdown]
# ###### Reduce topics based on the above  visualization
#
# We can reduce the number of topics after having trained a BERTopic model. The advantage of doing so is that you can decide the number of topics after knowing how many are created. It is difficult to predict before training your model how many topics that are in your documents and how many will be extracted. Instead, we can decide afterward how many topics seem realistic. So the "nr_topics" parameter should be adapted to a certain realistic number.

# %%
# choose here how many topics you want
# if you execute this cell, you need to reload the model if want to see all topics again
model.reduce_topics(newDF['corp'], nr_topics=10)

# %% [markdown]
# ### 1.2. Get value from you model

# %% [markdown]
# Load and test the model:

# %%
my_model = BERTopic.load("model_nneighbors15_ncomponents5_cluster_size120_unigram")

# %%
topics_my_model = my_model.get_topic_freq()
topics_my_model
# Out:
#     Topic  Count
# 0      -1  41941
# 1       0  28043
# 2       1   1152
# 3       2    648
# 4       3    609
# 5       4    558
# 6       5    511
# 7       6    497
# 8       7    436
# 9       8    432
# 10      9    429
# 11     10    412
# 12     11    386
# 13     12    385
# 14     13    357
# 15     14    310
# 16     15    301
# 17     16    296
# 18     17    292
# 19     18    288
# 20     19    284
# 21     20    284
# 22     21    261
# 23     22    257
# 24     23    247
# 25     24    205
# 26     25    188
# 27     26    186
# 28     27    184
# 29     28    183
# 30     29    177
# 31     30    176
# 32     31    174
# 33     32    170
# 34     33    170
# 35     34    168
# 36     35    167
# 37     36    166
# 38     37    165
# 39     38    160
# 40     39    156
# 41     40    154
# 42     41    153
# 43     42    152
# 44     43    149
# 45     44    145
# 46     45    145
# 47     46    136
# 48     47    132
# 49     48    131
# 50     49    124
# 51     50    120

# %% [markdown]
# Extract keywords per topic:

# %%
# learn how to extract keywords per topic
topic1 = my_model.get_topic(-1)
words1 = [t[0] for t in topic1]
words1
# Out:
# ['gebied',
#  'europees',
#  'goed',
#  'gaan',
#  'landbouw',
#  'komen',
#  'groot',
#  'geven',
#  'lid',
#  'duurzaam']

# %%
# get a list of all topics
topics_my_model = topics_my_model.reset_index(drop=True)
topics = topics_my_model['Topic'].to_list()

# %%
# make a dict of all topics and their keywords
words_per_topic = {}
for x in topics:
    keywords = my_model.get_topic(x)
    words = [t[0] for t in keywords]
    words_per_topic[x] = words

# %%
df_keywords = pd.DataFrame.from_dict(words_per_topic, orient='index')
df_keywords.head(12)
# Out:
#                 0                1                2            3  \
# -1         gebied         europees             goed         gaan
#  0       landbouw           gebied            groot         goed
#  1     ecologisch       economisch         economie  ecoregeling
#  2     biologisch         biomassa  biogrondstoffen     landbouw
#  3    toelichting       toezegging       toepassing     toekomst
#  4           park       westerpark             stad     tuinpark
#  5        hectare        provincie              nnn       natura
#  6           plan          project         planning        komen
#  7     instrument  instrumentarium          fiscaal  fiscaliteit
#  8   financiering       financieel      investering  financieren
#  9         sector        agrarisch        industrie         gaan
#  10          gaan             even           meteen          ver
#
#                    4           5               6              7             8  \
# -1          landbouw       komen           groot          geven           lid
#  0              boer         lid            gaan          komen         geven
#  1         circulair         eco      activiteit           vast    ecosysteem
#  2            houtig     product  biotechnologie       duurzaam           lid
#  3         toepassen     toename        toerisme  toekomstvisie      toestaan
#  4             groen        rust           haven     fietsroute          druk
#  5   bossenstrategie    grasland          gebied  natuurnetwerk    realiseren
#  6             geven      aanpak           groen           waar          gaan
#  7         evaluatie    regeling      financieel           doel        beleid
#  8            sector  instelling         privaat    mobiliseren    investeren
#  9             komen        goed         gesprek         kijken  glastuinbouw
#  10           gewoon        goed            waar            nou          snel
#
#                  9
# -1        duurzaam
#  0        mogelijk
#  1         klimaat
#  2        europees
#  3      toelichten
#  4        doorgaan
#  5       inrichten
#  6         ambitie
#  7       provincie
#  8   beleidsagenda
#  9           graag
#  10         zeggen

# %%
my_model.visualize_topics()
# Out:
# <iframe
#     scrolling="no"
#     width="670px"
#     height="670"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Get the topic of each paragraph
topics, _ = my_model.transform(newDF["corp"])

# %%
# Add the topic as a new column to your dataframe
newDF["topic"] = topics

# %%
# map the dict with keywords per topic to the final dataframe
newDF['keywords'] = newDF['topic'].map(words_per_topic)
newDF
# Out:
#                                                    title  paragraph_num  \
# 0      Contaminatie in het vlees van ‘grote grazers’ ...              4
# 1      Contaminatie in het vlees van ‘grote grazers’ ...              7
# 2      Contaminatie in het vlees van ‘grote grazers’ ...             13
# 3      Contaminatie in het vlees van ‘grote grazers’ ...             15
# 4      Contaminatie in het vlees van ‘grote grazers’ ...             17
# ...                                                  ...            ...
# 83947  Verslag Landbouw- en Visserijraad 17 januari 2022             31
# 83948  Verslag Landbouw- en Visserijraad 17 januari 2022             34
# 83949  Verslag Landbouw- en Visserijraad 17 januari 2022             39
# 83950  Verslag Landbouw- en Visserijraad 17 januari 2022             42
# 83951  Verslag Landbouw- en Visserijraad 17 januari 2022             46
#
#                                           paragraph_text  \
# 0      De Voorzitter van de Tweede Kamer der Staten-G...
# 1                                     : Parnassusplein 5
# 2      Correspondentie uitsluitend richten aan het re...
# 3      Betreft Contaminatie in het vlees van ‘grote g...
# 4      Geachte voorzitter, Ten behoeve van natuurbehe...
# ...                                                  ...
# 83947  Visserijraad van 17 januari 2022.\nOp 1 januar...
# 83948  Op 7 februari a.s. organiseert het Franse voor...
# 83949  Visserijraad van december jl. is uw Kamer geïn...
# 83950                          Zoals aan uw Kamer gemeld
# 83951  , was de Nederlandse inzet voor zeebaars om ee...
#
#       organizations_in_paragraph actors_in_paragraph       date_published  \
# 0                             []                  []  2022-12-14 00:00:00
# 1                             []                  []  2022-12-14 00:00:00
# 2                             []                  []  2022-12-14 00:00:00
# 3                             []                  []  2022-12-14 00:00:00
# 4                             []                  []  2022-12-14 00:00:00
# ...                          ...                 ...                  ...
# 83947                         []                  []  2022-01-26 00:00:00
# 83948                         []                  []  2022-01-26 00:00:00
# 83949                         []                  []  2022-01-26 00:00:00
# 83950                         []                  []  2022-01-26 00:00:00
# 83951                         []                  []  2022-01-26 00:00:00
#
#       organizations_list one_or_more_organizations  numb_unique_organizations  \
# 0                   ['']                       NaN                          1
# 1                   ['']                       NaN                          1
# 2                   ['']                       NaN                          1
# 3                   ['']                       NaN                          1
# 4                   ['']                       NaN                          1
# ...                  ...                       ...                        ...
# 83947               ['']                       NaN                          1
# 83948               ['']                       NaN                          1
# 83949               ['']                       NaN                          1
# 83950               ['']                       NaN                          1
# 83951               ['']                       NaN                          1
#
#       actors_list one_or_more_actors  numb_unique_actors  both_org_act  \
# 0            ['']                NaN                   1         False
# 1            ['']                NaN                   1         False
# 2            ['']                NaN                   1         False
# 3            ['']                NaN                   1         False
# 4            ['']                NaN                   1         False
# ...           ...                ...                 ...           ...
# 83947        ['']                NaN                   1         False
# 83948        ['']                NaN                   1         False
# 83949        ['']                NaN                   1         False
# 83950        ['']                NaN                   1         False
# 83951        ['']                NaN                   1         False
#
#                                                  content  \
# 0                                                [staat]
# 1                                       [parnassusplein]
# 2      [correspondentie, uitsluitend, richten, vermel...
# 3      [betreffen, contaminatie, vlees, groot, grazer...
# 4      [geacht, behoeve, uiterwaarde, specifiek, robu...
# ...                                                  ...
# 83947  [visserijraad, nemen, Frankrijk, voorzittersch...
# 83948  [organiseren, Frans, voorzitterschap, informee...
# 83949  [visserijraad, jl, ïnformeren, akkoord, vereni...
# 83950                                           [melden]
# 83951  [Nederlands, inzet, toename, realiseren, klein...
#
#                                                     corp  topic  \
# 0                                                  staat     -1
# 1                                         parnassusplein      0
# 2         correspondentie uitsluitend richten vermelding     32
# 3      betreffen contaminatie vlees groot grazer uite...     -1
# 4      geacht behoeve uiterwaarde specifiek robuust r...     -1
# ...                                                  ...    ...
# 83947  visserijraad nemen Frankrijk voorzitterschap r...     -1
# 83948  organiseren Frans voorzitterschap informeel la...      0
# 83949  visserijraad jl ïnformeren akkoord verenigen k...     19
# 83950                                             melden     -1
# 83951  Nederlands inzet toename realiseren kleinschal...     -1
#
#                                                 keywords
# 0      [gebied, europees, goed, gaan, landbouw, komen...
# 1      [landbouw, gebied, groot, goed, boer, lid, gaa...
# 2      [evaluatie, interview, doelmatigheid, conclusi...
# 3      [gebied, europees, goed, gaan, landbouw, komen...
# 4      [gebied, europees, goed, gaan, landbouw, komen...
# ...                                                  ...
# 83947  [gebied, europees, goed, gaan, landbouw, komen...
# 83948  [landbouw, gebied, groot, goed, boer, lid, gaa...
# 83949  [informatie, ïnformeren, platform, informeren,...
# 83950  [gebied, europees, goed, gaan, landbouw, komen...
# 83951  [gebied, europees, goed, gaan, landbouw, komen...
#
# [83952 rows x 17 columns]

# %% [markdown]
# # End products data of this notebook:
# ### 1. newDF - dataframe of documents used for our PowerBI dashboard containing:
#      a. split into paragraphs
#      b. topics
#      c. keywords
#      d. actors
#      e. organizations
#      f. date
# ### 2. model - trained Bertopic model

# %%
newDF.to_csv('newDF_nneighbors15_ncomponents5_cluster_size120_unigram.csv', index=False)

# %%
final_data_format = pd.read_csv('newDF_nneighbors15_ncomponents5_cluster_size120_unigram.csv')

# %% [markdown]
# We can check the paragraphs of a single topic:

# %%
topic_1 = final_data_format.loc[final_data_format['topic'] == 1]
topic_1
# Out:
#                                                    title  paragraph_num  \
# 218    Verslag van een schriftelijk overleg met de mi...              9
# 222    Verslag van een schriftelijk overleg met de mi...             14
# 224    Verslag van een schriftelijk overleg met de mi...             17
# 246    Verslag van een schriftelijk overleg met de mi...             49
# 248    Verslag van een schriftelijk overleg met de mi...             51
# ...                                                  ...            ...
# 82701  Antwoord op vragen van het lid Bouchallikh ove...             41
# 82718  Vaststelling van de begrotingsstaten van het M...             38
# 82748  Vaststelling van de begrotingsstaten van het M...            243
# 82885                                  Voorlopig verslag             10
# 83228  Begroting Landbouw, Natuur en Voedselkwaliteit...            454
#
#                                           paragraph_text  \
# 218    De leden van de vaste commissie voor Economisc...
# 222    De griffier van de vaste commissie voor Econom...
# 224    De leden van de vaste commissie voor Economisc...
# 246    Zo ja, kunt u aangeven waarom u SATL niet de g...
# 248    Aan de Voorzitter van de Eerste Kamer der Stat...
# ...                                                  ...
# 82701  – gelet op de consequenties voor gezondheid, c...
# 82718  Van dit overleg brengen de commissies bijgaand...
# 82748  Het CDA ziet die grote uitdagingen.\nNiet alle...
# 82885  COMMISSIE VOOR ECONOMISCHE ZAKEN EN KLIMAAT/LA...
# 83228  Dat is de eerste zin uit het partijlied van de...
#
#                               organizations_in_paragraph  \
# 218    ['Economische Zaken en Klimaat', 'Landbouw, Na...
# 222    ['Economische Zaken en Klimaat', 'Landbouw, Na...
# 224    ['Economische Zaken en Klimaat', 'Landbouw, Na...
# 246    ['Economische Zaken en Klimaat', 'Landbouw, Na...
# 248    ['Economische Zaken en Klimaat', 'Landbouw, Na...
# ...                                                  ...
# 82701                                                 []
# 82718  ['Landbouw, Natuur en Voedselkwaliteit', 'Land...
# 82748                                                 []
# 82885                                                 []
# 83228                                                 []
#
#                   actors_in_paragraph       date_published  \
# 218                                []  2022-02-09 00:00:00
# 222                          ['Boer']  2022-02-09 00:00:00
# 224                                []  2022-02-09 00:00:00
# 246    ['Adegeest', 'van der Linden']  2022-02-09 00:00:00
# 248                                []  2022-02-09 00:00:00
# ...                               ...                  ...
# 82701                              []  2022-12-16 00:00:00
# 82718  ['Geurts', 'Mulder', 'Jansma']  2022-04-29 00:00:00
# 82748                              []  2022-04-29 00:00:00
# 82885                              []  2021-03-16 00:00:00
# 83228                              []  2021-12-01 00:00:00
#
#                                       organizations_list  \
# 218    ['Economische Zaken en Klimaat', 'Landbouw', '...
# 222    ['Economische Zaken en Klimaat', 'Landbouw', '...
# 224    ['Economische Zaken en Klimaat', 'Landbouw', '...
# 246    ['Economische Zaken en Klimaat', 'Landbouw', '...
# 248    ['Economische Zaken en Klimaat', 'Landbouw', '...
# ...                                                  ...
# 82701                                               ['']
# 82718  ['Landbouw', 'Natuur en Voedselkwaliteit', 'La...
# 82748                                               ['']
# 82885                                               ['']
# 83228                                               ['']
#
#       one_or_more_organizations  numb_unique_organizations  \
# 218                        True                          3
# 222                        True                          3
# 224                        True                          3
# 246                        True                          3
# 248                        True                          3
# ...                         ...                        ...
# 82701                       NaN                          1
# 82718                      True                          2
# 82748                       NaN                          1
# 82885                       NaN                          1
# 83228                       NaN                          1
#
#                           actors_list one_or_more_actors  numb_unique_actors  \
# 218                              ['']                NaN                   1
# 222                          ['Boer']               True                   1
# 224                              ['']                NaN                   1
# 246    ['Adegeest', 'van der Linden']               True                   2
# 248                              ['']                NaN                   1
# ...                               ...                ...                 ...
# 82701                            ['']                NaN                   1
# 82718  ['Geurts', 'Mulder', 'Jansma']               True                   3
# 82748                            ['']                NaN                   1
# 82885                            ['']                NaN                   1
# 83228                            ['']                NaN                   1
#
#        both_org_act                                            content  \
# 218           False  ['lid', 'vast', 'economisch', 'zaak', 'klimaat...
# 222            True  ['griffier', 'vast', 'economisch', 'zaak', 'kl...
# 224           False  ['lid', 'vast', 'economisch', 'zaak', 'klimaat...
# 246            True  ['aangeven', 'satl', 'vragen', 'gegeven', 'ver...
# 248           False  ['één', 'staat', 'lid', 'vast', 'economisch', ...
# ...             ...                                                ...
# 82701         False  ['let', 'consequentie', 'cultureel', 'erfgoed'...
# 82718          True  ['overleg', 'brengen', 'commissie', 'bijgaand'...
# 82748         False  ['zien', 'groot', 'uitdaging', 'wennen', 'rand...
# 82885         False      ['economisch', 'zaak', 'klimaat', 'landbouw']
# 83228         False  ['één', 'zin', 'partijlied', 'socialistisch', ...
#
#                                                     corp  topic  \
# 218    lid vast economisch zaak klimaat landbouw same...      1
# 222    griffier vast economisch zaak klimaat landbouw...      1
# 224    lid vast economisch zaak klimaat landbouw bela...      1
# 246    aangeven satl vragen gegeven verstrekken reden...      1
# 248    één staat lid vast economisch zaak klimaat lan...      1
# ...                                                  ...    ...
# 82701        let consequentie cultureel erfgoed economie      1
# 82718  overleg brengen commissie bijgaand redigeren w...      1
# 82748  zien groot uitdaging wennen randvoorwaarde soc...      1
# 82885                   economisch zaak klimaat landbouw      1
# 83228  één zin partijlied socialistisch mooi zeggen s...      1
#
#                                                 keywords
# 218    ['ecologisch', 'economisch', 'economie', 'ecor...
# 222    ['ecologisch', 'economisch', 'economie', 'ecor...
# 224    ['ecologisch', 'economisch', 'economie', 'ecor...
# 246    ['ecologisch', 'economisch', 'economie', 'ecor...
# 248    ['ecologisch', 'economisch', 'economie', 'ecor...
# ...                                                  ...
# 82701  ['ecologisch', 'economisch', 'economie', 'ecor...
# 82718  ['ecologisch', 'economisch', 'economie', 'ecor...
# 82748  ['ecologisch', 'economisch', 'economie', 'ecor...
# 82885  ['ecologisch', 'economisch', 'economie', 'ecor...
# 83228  ['ecologisch', 'economisch', 'economie', 'ecor...
#
# [1152 rows x 17 columns]

# %%
topic_1['paragraph_text'].to_list()
# Out:
# ['De leden van de vaste commissie voor Economische Zaken en Klimaat / Landbouw, Natuur en Voedselkwaliteit 1 Samenstelling:',
#  'De griffier van de vaste commissie voor Economische Zaken en Klimaat / Landbouw, Natuur en Voedselkwaliteit, De Boer BRIEF VAN DE VOORZITTER VAN DE VASTE COMMISSIE VOOR ECONOMISCHE ZAKEN EN KLIMAAT / LANDBOUW, NATUUR EN VOEDSELKWALITEIT',
#  'De leden van de vaste commissie voor Economische Zaken en Klimaat / Landbouw, Natuur en Voedselkwaliteit hebben met belangstelling kennisgenomen van uw brief 3 Kamerstukken I, 2021–2022, 35\xa0334,\xa0AK.',
#  'Zo ja, kunt u aangeven waarom u SATL niet de gevraagde gegevens verstrekt?\nBent u het eens met de redenering van Leon Adegeest dat zonder de invoer van stikstofgegevens de daadwerkelijke stikstofdepositie op de Natura 2000-gebieden vanuit Lelystad Airport niet berekend kan worden?\nDe leden van de vaste commissie voor Economische Zaken en Klimaat / Landbouw, Natuur en Voedselkwaliteit zien uw reactie met belangstelling tegemoet en ontvangen deze graag uiterlijk 14\xa0januari 2022.\nDe voorzitter van de vaste commissie voor Economische Zaken en Klimaat / Landbouw, Natuur en Voedselkwaliteit, L.P. van der Linden BRIEF',
#  'Aan de Voorzitter van de Eerste Kamer der Staten-Generaal Den Haag, 7\xa0februari 2022\nDe leden van de vaste commissie voor Economische Zaken en Klimaat/Landbouw, Natuur en Voedselkwaliteit hebben op 14\xa0december 2021 naar aanleiding van de brief van mijn ambtsvoorganger van 12\xa0november 2021 inzake de voortgang van stikstofproblematiek (Kamerstuk 35\xa0334,\xa0AK) een aantal vragen gesteld (uw kenmerk: 168745.03U).',
#  'Met mijn brief van 23\xa0november jl. (Kamerstuk 35\xa0925\xa0XIV, nr.\xa021) heb ik uw Kamer geïnformeerd over de uitkomst van de praktijktoets met betrekking tot de ecoregelingen en het verdere proces geschetst.',
#  'De akkerbouwsector is hierbij betrokken.\nTevens wordt overeenkomstig de motie van het lid Tjeerd de Groot c.s. de ecoregeling gebiedsgericht uitgewerkt door eco-activiteiten in het puntensysteem gebiedsgericht te waarderen.\nHiermee kan ook meer doelgericht op de opgaven op het gebied van stikstof, klimaat en biodiversiteit worden gestuurd.\nUw Kamer wordt over de voortgang van invulling van de ecoregeling op de hoogte gehouden.',
#  'Ecoregeling:',
#  'Economische impact analyse',
#  'Op verzoek van het bestuurlijk overleg, LTO en uw Kamer heeft de WUR een nieuwe economische impact analyse gedaan op twee onderdelen:\nberekening van inkomenseffecten en een inschatting van kosten en gederfde inkomsten als gevolg van de GLMC’s.\nBijgaand treft u het rapport van de WUR aan.\nDaarmee geef ik uitvoering aan de motie van het lid Van Campen van 24\xa0juni 2021 (Kamerstuk 21 501-32, nr.\xa01310) om de uitkomsten van pilots, klankbordgroepen en uitvoeringstoetsen met de Kamer te delen en betrekken bij het op te stellen NSP.\nDe Minister van Landbouw, Natuur en Voedselkwaliteit, C.J. Schouten',
#  'De Partij voor de Dieren heeft daar aangifte van gedaan bij de politie.\nHet doden van deze bedreigde en beschermde diersoort is immers strafbaar.\nWat gaat het kabinet eraan doen om te voorkomen dat in de toekomst ook andere wolven in Nederland worden doodgeschoten?\nWat doet het kabinet om te bevorderen dat de dader wordt aangehouden en berecht?\nDe leden van de vaste commissie voor Economische Zaken en Klimaat / Landbouw, Natuur en Voedselkwaliteit zien uw reactie met belangstelling tegemoet en ontvangen deze graag uiterlijk 21\xa0januari 2022.\nDe voorzitter van de vaste commissie voor Economische Zaken en Klimaat / Landbouw, Natuur en Voedselkwaliteit, L.P. van der Linden BRIEF',
#  '· Beeld van een robuust ecologisch systeem Waddenzee nader duiden:',
#  'Beschrijven van samenhangende criteria die gehanteerd worden bij de beoordeling van de impact van gebruiksfuncties en op basis waarvan bepaald kan worden of iets vanuit ecologisch oogpunt wel/niet acceptabel is (toetsingskader);',
#  'Landbouwontwikkelingsgebied (functie: grootschalige landbouw), N343 economische zone (functies: economie en infrastructuur), gemengd gebied (functies: wonen en bedrijvigheid) :',
#  'Landbouwontwikkelingsgebied (functie: grootschalige landbouw), N343 economische zone (functies: economie en infrastructuur).',
#  '’s, verbreden economische basis landgoed De Groote Scheere (doelgroepverbreding).',
#  'Economie en infrastructuur\nRecreatie en toerisme',
#  'Circulaire Economie gemeente',
#  'In 2024 bestaat er een (lokaal) koplopernetwerk van projectontwikkelaars, bouwpartijen, ingenieursbureaus en andere sympathisanten die met hun bedrijfsvoering actief de circulaire economie stimuleren.',
#  'De urgentie voor bedrijven om met de circulaire economie aan de slag te gaan wordt steeds groter.\nMaterialen en grondstoffen worden steeds duurder en schaarser, regelgeving strenger en de consument kritischer.\nGemeenten hebben een groot belang bij een circulair bedrijfsleven.\nHet biedt volop kansen voor een gezonde regionale economie, werkgelegenheid en het milieu (denk aan vermindering van afval, CO2 en stikstof).\nVoor de BUCH gemeenten zijn er drie sectoren waar de eerste jaren de aandacht naar toe gaat:',
#  'Met een duurzame én sterke economie.',
#  'Op naar een circulaire economie in 2050!',
#  'Dit beleidsplan geeft samen met de uitvoeringsagenda weer hoe de gemeente Uitgeest in de periode van 2022 tot 2026 toewerken naar de gestelde doelstellingen voor een lokale circulaire economie.\nWij richten ons in eerste instantie op de bestuurders van de gemeente en medewerkers van de BUCH werkorganisatie, van uitvoering tot management.\nDaarnaast is dit stuk openbaar toegankelijk voor iedereen die in ons beleid geïnteresseerd is.',
#  '9 1 Circulaire economie als basis voor het behalen van klimaatdoelstellingen',
#  'Nederland heeft als doel gesteld om in 2050 100% circulair te zijn.\nDe gemeente ziet de urgentie en wil actief naar dit doel toe werken.\nIn een lineaire economie doen we alsof grondstoffen oneindig voorradig zijn en is ontwikkeling alleen gericht op financiële groei.\nDit is een onhoudbare situatie voor zowel ecosystemen als onze gezondheid en de economie.\nGrondstoffen raken op en de vernietiging van de natuur en biodiversiteit leidt tot grote problemen.\nDenk hierbij aan een slechte luchtkwaliteit, vervuilde wateren, een onvruchtbare bodem, maar ook meer pandemieën3.',
#  'Zo’n circulaire economie komt er niet vanzelf.',
#  'De noodzaak van een circulaire economie',
#  'De circulaire economie is noodzakelijk5.',
#  '2.1 - Facetten van de circulaire economie in één geheel',
#  'Het richt zich op het bereiken van klimaatneutraliteit en een ontkoppeling van economische groei en het gebruik van hulpbronnen.\nHet concurrentievermogen van de EU op de lange termijn wordt gewaarborgd en men denkt hierbij ongeveer 700.000 nieuwe banen te creëren.\nHet plan richt zich op elektronica, textiel, plastic, 13 verpakkingen en voedsel.\nDe regelgeving voor het uitbannen van plastic wegwerpartikelen in 2021 is een voorbeeld van de uitvoering.',
#  'Provincie Noord-Holland is volop bezig met het inzetten op een circulaire economie door de ‘Actieagenda Circulaire Economie 2021-2025’ en via de Voedselvisie met betrekking tot regeneratieveen kringlooplandbouw .\nDeze agenda richt zich op twee inhoudelijke sporen:',
#  'De provincie wilt de impact van de circulaire economie ook in hun eigen organisatie vergroten.\nDit doen zij o.a. door circulair in te kopen en aan te besteden, maar ook door circulaire aanleg, beheer en onderhoud van de provinciale infrastructuur.\nDe provincie zet expliciet in op het versterken van de samenwerking met gemeenten en regionale samenwerkingsverbanden (zoals circulaire initiatieven van organisaties of inwoners) om hun doelen te behalen.\nGemeenten en regio’s kunnen een grote rol spelen door in de uitvoering van hun taken circulaire principes toe te passen en circulair in te kopen.\nDit kan bijvoorbeeld op het gebied van huishoudelijk afval, grond-, wegen waterbouw (GWW), woningbouw en openbare ruimte.',
#  '7 Week van de circulaire economie - NHNEXT 8 Afval scheiden:',
#  'https://nhnext.nl/ https://nhnext.nl/week-van-de-circulaire-economie-2022/ https://www.milieucentraal.nl/minder-afval/afval-scheiden/afval-scheiden-cijfers-en-kilo-s/#:~:text=De%20Nederlandse%20overheid%20wil%20in,door%20afval%20beter%20te%20scheiden.',
#  'Zie extra toelichting met betrekking tot inwoners in bijlage 5.4.\nEindresultaat \uf0b7 Draagvlak bij bewoners voor circulaire economie op zowel inhoud, vorm en invulling.',
#  'De circulaire economie vergt nieuwe kennis en een andere manier van denken.\nDit geldt voor medewerkers door de gehele organisatie.\nManagers en financieel specialisten moeten bijvoorbeeld op zoek naar ‘financiële oplossingen’ voor de circulaire doelstellingen die gesteld zijn.',
#  "'Het Nieuwe Normaal' - Cirkelstad https://gprsoftware.nl/over-gpr-software/ https://kenniskaarten.hetgroenebrein.nl/kenniskaart-circulaire-economie/wat-is-ketensamenwerking/ https://kenniskaarten.hetgroenebrein.nl/kenniskaart-circulaire-economie/wat-is-ketensamenwerking/ https://ecochain.com/nl/knowledge-nl/milieuprestatie-gebouwen-berekening/ https://www.metropoolregioamsterdam.nl/wp-content/uploads/2021/11/MRA-Convenant-Houtbouw-finale-versie-21-10-2021.pdf https://toekomstbestendigbouwen.nl/ https://www.betonakkoord.nl/ https://www.cirkelstad.nl/project/samen-versnellen/ 29 Figuur 6.3 – Milieu Prestatie Gebouwen (MPG)",
#  'De regio blinkt uit in water, agri en food, (duurzame) energie en toerisme.\nDe afdeling Economische Zaken (EZ) is samen met regio Alkmaar betrokken bij de ontwikkeling van de economische agenda voor Noord-Holland-Noord (NHN).',
#  'Dit heeft als doel om de economische groei aan te jagen en te zorgen voor een duurzame en sterke economische structuur.',
#  'De circulaire economie is in deze agenda onderdeel van meerdere thema’s;',
#  'energietransitie, digitaal/IT, innovatie/incubatie en bedrijventerreinen.\nDeze opdracht wordt uitgevoerd door het Ontwikkelingsbedrijf NHN en de planning is om de economische agenda NHN eind 2022 vast te stellen.\nOok vanuit het klimaatprogramma streeft de gemeente ernaar om haar ondernemers zo goed mogelijk voor te bereiden op de veranderingen die een nieuwe duurzame wereld met zich mee gaan brengen.\nVanuit het thema energietransitie wordt de verduurzaming van individuele bedrijven en bedrijventerreinen binnen de BUCH gemeenten gefaciliteerd.\nZo wordt met de regio Alkmaar verkend hoe de verduurzaming van bedrijventerreinen op regionaal niveau kan worden vormgegeven.\nWest-Friesland23 is daarbij een mooi voorbeeld.',
#  'Binnen het beleid circulaire economie',
#  'In 2023 hebben we 15% van de restaurants en logiesverstrekkende bedrijven bereikt met informatie over de kansen van de circulaire economie.',
#  'Eind 2025 hebben we 25% van de toerisme bedrijven bereikt met informatie over de kansen van de circulaire economie.',
#  'Eind 2024 zijn alle bedrijventerreinen geïnformeerd over de kansen van de circulaire economie.',
#  'Circulaire Economie',
#  'DB = Duurzame Bedrijfsvoering, CE = Circulaire Economie, PNH\n=',
#  'Circulaire Economie, PNH',
#  'Extra toelichting waarom bedrijven de circulaire economie moeten omarmen',
#  'De Volkskrant, 10 november 2017, «Rabobank blijft mesttransporteurs steunen ondanks fraudeverdenkingen» (https://www.volkskrant.nl/economie/rabobank-blijft-mesttransporteurssteunen-ondanks-fraudeverdenkingen~b95a82d8/)',
#  '19 Is de Minister van Economische Zaken en Klimaat bereid om te onderzoeken hoe het versterken van biodiversiteit en natuur meegenomen kan worden bij het vergeven van subsidies voor windturbines en zonnepanelen?',
#  "· de brief van de minister van Landbouw, Natuur en Voedselkwaliteit d.d. 19 oktober 2022 inzake reactie op verzoek commissie op notitie '2023 overgangsjaar voor GLB en 7e APN' van LTO Nederland (28625, nr. 344).\nVan dit overleg brengen de commissies bijgaand geredigeerd woordelijk verslag uit.\nDe voorzitter van de vaste commissie voor Landbouw, Natuur en Voedselkwaliteit, Geurts\nDe voorzitter van de vaste commissie voor Economische Zaken en Klimaat, Agnes Mulder\nDe griffier van de vaste commissie voor Landbouw, Natuur en Voedselkwaliteit, Jansma",
#  'Agency (EPA)',
#  'In delen van de Noordzee wordt de bodem meer dan eens per jaar omgewoeld door vistuig.\nBodemberoerende visserij vormt een groot risico voor de ecologische waarde van de natuur en voor de ecosysteemdiensten.',
#  '3 https://www.science.org/content/article/use-too-hot-climate-models-exaggerates-impactsglobal-warming 4 https://www.nature.com/articles/d41586-022-01192-2',
#  'al in 2023 beschikbaar zijn in de ecoregeling.\nInvesteringsregelingen vallen onder de tweede pijler en niet onder de ecoregeling.\nDaarin is het mogelijk om bijvoorbeeld de eco-ploeg, mechanisch onkruid wieden en taakkaarten subsidiabel te maken.\nDit wordt nog verder uitgewerkt.\nMeerdere van de andere genoemde activiteiten staan op de zogeheten longlist om toegevoegd te worden aan het keuzemenu zodra dat technisch mogelijk is, naar verwachting in 2024 of 2025.\nBijvoorbeeld niet-kerende grondbewerking en precisielandbouw zijn activiteiten die ik graag nu al zou willen toevoegen, maar waar monitoring en controle helaas in 2023 nog niet zonder risico van correctie door de Europese Commissie mogelijk zijn.\nDe komende jaren zal ik, in samenwerking met de sector en eerdergenoemde partijen, de ecoregeling verder ontwikkelen en de lijst eco-activiteiten verder uitbreiden.\nGezamenlijke vragen en opmerkingen van de leden van de PvdAen van de GroenLinks-fractie\nDe leden van de fracties van de PvdA en GroenLinks hebben kennisgenomen van de brief van de Minister van 13 mei 2022 over de geannoteerde agenda Landbouwen',
#  'De Minister gaf daarbij aan dat de voorbereidingen voor de uitvoering niet op tijd voor invoering per 2023 gereed zijn.\nDeze ledenhoren graag of het klopt dat niet kerende grondbewerking tot nu toe niet op de lijst voor de eco-regeling heeft gestaan.\nZij horen graag wanneer met deze voorbereiding is begonnen en waarom de komende maanden deze voorbereiding niet afgerond zou kunnen worden.\nDeze leden zijn van mening dat alle sectoren van begin af aan een evenredige kans moeten maken om gebruik te maken van de eco-regeling.',
#  'Daarin zijn ook wettelijke doelstellingen opgenomen voor stikstofreductie.\nHet realiseren van de doelstellingen is met deze aanpak steviger gewaarborgd.\nCoherentie van beleid\nIk onderschrijf de aanbeveling om beleid op het gebied van natuur en biodiversiteit doeltreffender én doelmatiger te maken door grotere coherentie tussen natuurbeleid en ander beleid (voedselproductie en -consumptie, water, ruimtelijke ordening, milieu, economisch beleid, internationale handel, energie).\nOm deze coherentie te vergroten verkent het kabinet in het kader van het Nationaal Programma',
#  'De uitvoeringsplannen voor zes werklocaties zijn ontvangen, afronding beschikkingen voorzien in Q1 2023 Tussenevaluatie voorzien voor 2023 EH EC Economie',
#  '43 Circulaire economie\n43',
#  'Hoewel het aantal overschrijdingen van de ecologische normen voor gewasbeschermingsmiddelen de laatste jaren afneemt, gaat de verbetering in het aantal normoverschrijdingen voor de ecologie en de drinkwaterbereiding op dit moment onvoldoende snel om de doelen van de Kaderrichtlijn Water in 2027 te kunnen halen.\nEen complicerende factor is ook het toenemende aantal niet-toetsbare gewasbeschermingsmiddelen (middelen die vanwege technische belemmeringen niet tot op het niveau van de norm kunnen worden geanalyseerd).',
#  '2050 periode 2021-2026 is in het Opdrachtgeversoverleg Eems-Dollard 2050 vastgesteld.\nIn dit tweede programmaplan is het ecologisch streefbeeld aangescherpt en wordt nadrukkelijker ingezet op klimaatadaptatie.\nOok worden de lopende projecten verbonden met beleidsdoelen als leefbaarheid, recreatie en het toekomstperspectief voor de landbouw.\nHet programmaplan voor 2021-2026 staat vooral in het teken van opschaling:\nvan verkenningen en pilots naar omvangrijke projecten die structureel werk maken van het ecologisch herstel van het Eems-Dollard estuarium.',
#  'Eind 2021 hebben de partijen van het Gebiedsoverleg Zuidwestelijke Delta, met steunbetuiging van de in het gebied opererende belangenorganisaties, een samenwerkingsovereenkomst ondertekend.\nDaarmee bevorderen de betrokken provincies, waterschappen, gemeenten, het Rijk, samenwerkende ondernemers en maatschappelijke organisaties de samenhangende aanpak van de opgaven voor water en klimaatadaptatie in de Zuidwestelijke Delta.\nDe ambitie is om de eerste delta ter wereld te zijn die heeft uitgedacht, uitgewerkt én in gang gezet wat nodig is om in 2050 voorbereid te zijn op de gevolgen van klimaatverandering.\nHet realiseren van een klimaatbestendig veilige, ecologisch veerkrachtige en economisch vitale delta blijft daarbij het hoofddoel.',
#  'Circulaire economie',
#  'Vanaf 2018 is er de nodige maatschappelijke en politieke aandacht voor het diepe plassenbeleid.\nDaarbij deed zich onder andere de vraag voor of een verondieping wel ecologische meerwaarde heeft en of het wel wenselijk is om grond en baggerspecie hiervoor te importeren.\nEen verondieping kan bijvoorbeeld plaatsvinden in het kader van de ontwikkeling van natuur en of in samenhang met andere maatregelen, zoals ruimte voor de rivierprojecten of het baggeren van onze rivieren om deze veilig en vlot bevaarbaar te houden.\nIn 2021 is een beleidsonderzoek diepe plassen gestart.\nOnderdeel van dit onderzoek is een bestuurlijke dialoog.\nSamen met publiek en private partijen worden de belangrijkste knelpunten rondom de diepe plassenproblematiek in beeld gebracht, gesprekken gevoerd over de onderliggende belangen en bouwstenen voor nieuw beleid in beeld gebracht.\nOok wordt onderzocht of de regels onder de Omgevingswet, die op 1-1-2023 in werking treedt, voldoende robuust zijn.\nVoor de zomer van 2022 wordt de Tweede Kamer over de uitkomsten van het onderzoek geïnformeerd.',
#  'Economische Zaken en Klimaat FAIR Findable, Accessible, Interoperable, Re-usable',
#  'De vaste commissie voor Landbouw, Natuur en Voedselkwaliteit, de vaste commissie voor Economische Zaken en Klimaat, de vaste commissie voor Infrastructuur en Waterstaat en de vaste commissie voor Volksgezondheid, Welzijn en Sport hebben op 9 februari 2022 overleg gevoerd met mevrouw Heijnen, Staatssecretaris van Infrastructuur en Waterstaat, en de heer Staghouwer, Minister van Landbouw, Natuur en Voedselkwaliteit, over:\n– de brief van de Minister van Landbouw, Natuur en Voedselkwaliteit d.d. 23 april 2021 inzake contouren ODEcompensatieregeling industrie en glastuinbouw (Kamerstuk 30 196, nr. 755);\n– de brief van de Minister van Landbouw, Natuur en Voedselkwaliteit d.d. 31 mei 2021 inzake eindrapport studie over de invloed van generieke maatregelen op de energietransitie van de glastuinbouw (Kamerstuk 32 627, nr. 34);\n– de brief van de Minister van Landbouw, Natuur en Voedselkwaliteit d.d. 15 juli 2021 inzake rapport effecten van actuele ontwikkelingen op prognoses',
#  'Van dit overleg brengen de commissies bijgaand geredigeerd woordelijk verslag uit.\nDe voorzitter van de vaste commissie voor Landbouw, Natuur en Voedselkwaliteit, Geurts\nDe voorzitter van de vaste commissie voor Economische Zaken en Klimaat, Agnes Mulder\nDe voorzitter van de vaste commissie voor Infrastructuur en Waterstaat, Tjeerd de Groot\nDe voorzitter van de vaste commissie voor Volksgezondheid, Welzijn en Sport, Smals\nDe griffier van de vaste commissie voor Landbouw, Natuur en Voedselkwaliteit, Jansma Tweede Kamer, vergaderjaar 2021–2022, 32 627, nr. 38',
#  'De Minister van Economische Zaken en Klimaat, S.A. Blok 4 Kamerstukken II, 2020/2021, 35 770, nr. 7.',
#  'Zoals het Gemeenschappelijk Landbouwbeleid (Kamerstuk 28\xa0625, nr. 291), het nieuwe Circulaire Economie\nActieplan (Kamerstuk 22\xa0112, nr. 2865) en de nieuwe Omgevingswet.',
#  'KLIMAATNEUTRAAL IN 2050 Hoeksche Waard energieneutraal in 2040\nIn 2050 is Hoeksche Waard 100 % circulair\nIn 2050 hebben we weerkrachtige ecosystemen in Hoeksche Waard Hoeksche Waard\nis in 2050 volledig klimaatadaptief Inleiding GEMEENTE HOEKSCHE WAARD 3',
#  'energietransitie, circulaire economie, biodiversiteit en klimaatadaptatie.\nVoorbeelden van communicatie en/of participatie op themaniveau zijn onder meer de Innovatietafels voor circulaire economie, de Energietafels voor energieneutraal en de digitale bijeenkomst Energietransitie.',
#  'In de Hoeksche Waard werken we aan circulaire economie als de nieuwe standaard.',
#  'Vanuit het Deltaplan Biodiversiteitsherstel werken we met inmiddels meer dan 100 partners aan het vergroten van de biodiversiteit.\nWe willen u oproepen om – mocht u dit niet nog hebben gedaan - een concrete beleidsagenda en uitvoeringsprogramma voor natuur en biodiversiteit op te stellen.\nAls gemeente bent u vanwege uw invloed van groot belang en kunt u op vele manieren een bijdrage leveren.\nDenk bijvoorbeeld aan het creëren van meer openbaar groen en terugdringen verstening, ecologisch inrichten van de openbare ruimte en ecologisch beheer van openbaar groen en last but not least door actief de samenwerking te zoeken met burgers, bedrijven en agrariërs.\nIn de bijlage zijn de verschillende mogelijkheden inclusief voorbeelden te vinden.',
#  'Creëren meer openbaar groen/terugdringen verstening\nHet creëren van meer openbaar groen en het terugdringen van de verstening zorgt er voor dat er meer ruimte ontstaat voor biodiversiteit.\nVan belang hierbij is ook te zorgen voor verbindingszones.\nEcologische inrichting van openbare ruimte\nEen ecologische inrichting zorgt voor een grote toegevoegde waarde voor de biodiversiteit.\nHierbij gaat het vooral om het creëren van structuur, diversiteit in omstandigheden en gebruik van inheems plantenmateriaal.\nNiet alleen openbaar groen is hier van belang, maar er zijn ook veel mogelijkheden op het gebied van natuurinclusief bouwen.\nEcologisch beheer van openbaar groen\nStap als gemeente over op ecologisch beheer van het openbaar groen.\nEr komt steeds meer aandacht voor ecologisch bermbeheer, maar ook op andere groenstukken heeft ecologisch beheer een positief effect op de biodiversiteit.\nEcologisch beheer zorgt er voor dat er altijd leefruimte en voedsel beschikbaar blijft voor verschillende soorten.\nSamenwerking met en bewustwording van burgers/bedrijven\nNaast dat je als gemeente zelf het groen in de openbare ruimte anders kunt inrichten en beheren, kunnen burgers en bedrijven binnen de gemeente zich ook inzetten om de biodiversiteit te vergroten.\nAls gemeente kun je dit stimuleren, door ludieke acties, informatieverstrekking, subsidies en samenwerkingen met andere partijen.',
#  '• Natuurvriendelijke straatverlichting • Natuurinclusief bouwen\n• Ecologisch bermbeheer\n• Groene tuinen\n• Groene daken/daktuinen\n• Verticaal groen •',
#  '32 3.4 Duurzame, circulaire economie\n34 3.4.1 Stand van het milieu duurzame, circulaire economie\n34 3.4.2 Trends en ontwikkelingen duurzame, circulaire economie',
#  'Opgaven duurzame, circulaire economie',
#  'In het tweede hoofdstuk van deze NRD wordt ten eerste beschreven wat het NMP inhoudt, de tijdshorizon wordt geschetst en wat de juridische status is.\nTen tweede wordt de reikwijdte van het NMP, met een focus op drie hoofdopgaven (Vitale Ecosystemen, Gezonde Leefomgeving en Duurzame, Circulaire Economie), aangegeven.\nTen slotte worden de doelen van het NMP geduid.',
#  'De drie NMP-hoofdopgaven beïnvloeden elkaar.\nZo zullen economische activiteiten invloed hebben op vitale ecosystemen in de vorm van beslag op eindige grondstofvoorraden, beïnvloeding met natuurvreemde stoffen en ruimtebeslag.\nIn hoeverre een leefomgeving gezond wordt, hangt af van de mate waarin de economie kan verduurzamen.\nEr is een duidelijke invloed van duurzame, circulaire economie op de andere twee hoofdopgaven.\nAls die invloed te ver negatief is, dan moeten vanuit die andere hoofdopgaven kaders gesteld worden aan de economische activiteiten.\nIn hoeverre de economie zich kan ontplooien, hangt ook af van de stand van de gezonde leefomgeving (bv. het welbevinden van werknemers) en van de vitale ecosystemen (bv. de beschikbare milieuruimte).\nDeze onderlinge relaties zijn schematisch weergegeven in Figuur 2.',
#  'chemisch schoon en ecologisch gezond water voor duurzaam gebruik.',
#  'Haalbaarheid van het bereiken van de doelen van de Grondwaterrichtlijn9 (voor zover aanvullend op de KRW10);\nkwaliteitseisen ten aanzien van chemische parameters.',
#  '• Realiseren van een toekomstbestendige, circulaire economie.',
#  'Rijksbrede programma circulaire economie',
#  'Bij deze richtlijn worden maatregelen vastgesteld om het milieu en de menselijke gezondheid te beschermen door afvalproductie en de negatieve gevolgen van afvalproductie en -beheer te Circulaire economie: Nederland is in 2050 circulair.\nDe resterende milieudruk van het grondstoffengebruik past bij de draagkracht van de natuur.\nMet een circulaire economie dragen we bij aan het voorkomen van klimaatverandering, biodiversiteitsverlies, vervuiling en leveringsrisico’s.28 29',
#  'Mogelijke doelen voor een circulaire economie (01.07.2021).',
#  '33 https://www.rijksoverheid.nl/documenten/kamerstukken/2021/07/14/concretisering-doelen-circulaire-economie 34',
#  'Bouwstenen voor een veilig, gezond en schoon leefmilieu.\nHoofdopgave Wettelijke of beleidsbasis Thema’s en milieudoelen voorkomen of te verminderen, door de algehele gevolgen van het gebruik van hulpbronnen te beperken en door de efficiëntie van dergelijk gebruik te verbeteren, die van cruciaal belang zijn voor de overgang naar een circulaire economie.',
#  'Stand van het milieu, trends en opgaven\nIn hoofdstuk 2 (paragraaf 2.3) zijn de drie hoofdopgaven van het Nationaal MilieuProgramma en onderliggende thema’s toegelicht.\nDaarnaast is bekeken welke huidige beleidsdoelen er zijn (Tabel 1).\nDit hoofdstuk geeft een verdere uitleg van de drie hoofdopgaven (Vitale Ecosystemen, Gezonde Leefomgeving en Duurzame, Circulaire Economie) voor het NMP.\nVoor elk van de drie hoofdopgaven wordt steeds de stand van het milieu, de trends en ontwikkelingen en eerste beeld bij de opgaven die daaruit voortvloeien voor het NMP beschreven.\nDeze opgaven zijn nog niet uitgekristalliseerd en geven de huidige inzichten weer.\nDit hoofdstuk is daarom bedoeld om de eerste inzichten te delen op basis waarvan in het kader van deze NRD eenieder kan reageren.',
#  'De laatste decennia dalen de jaargemiddelde stikstofdioxide (NO2)-concentraties.\nIn de periode 1993-2019 daalden NO2-concentraties op regionale achtergrondstations van 25 naar 14 µg/m³, met in 2020 een nog lagere waarde van 12 µg/m³ door de COVID-19 maatregelen.\nDe WHO-advieswaarde is echter bijgesteld van 40 µg/m³ naar 10 µg/m³.\nOp stedelijke achtergronden de verkeersbelaste straatstations daalden de NO2-concentraties in de periode 2004-2019 significant met (gemiddeld) 0,8 en 1,1 µg/m³ per jaar.74',
#  'Belangrijk onderdeel van een duurzame economie is hoe er met afval omgegaan wordt.',
#  'De opgave duurzame, circulaire economie heeft ook raakvlakken met de andere opgaven in het NMP:\nvitale ecosystemen en gezonde leefomgeving.\nBij de verduurzaming van de economie dient ook rekening gehouden te worden met de beheersing van risico’s op afwenteling van milieuschade.\nHieronder valt ten eerste het voorkomen van afwenteling naar elders, waarmee andere landen/delen van de wereld bedoeld wordt.\nDe manier waarop Nederland zijn de economie inricht, en wel of niet een duurzame economie opbouwt, heeft ook gevolgen in andere landen.\nTen tweede dient afwenteling tussen milieuthema’s voorkomen te worden.\nVooruitgang op een milieuthema mag niet leiden tot stilstand of achteruitgang van de ontwikkelingen binnen een ander (milieu)thema.\nTen derde dient afwenteling over generaties voorkomen te worden, waarbij toekomstige generaties niet de dupe van huidige keuzes mogen worden.',
#  'Ontkoppeling tussen economische groei en milieudruk;',
#  'Onder beleidsmaatregelen verstaan we in het planMER de beleidsvoornemens die er zijn om invulling te geven aan de hoofdopgave van het NMP: voor vitale ecosystemen, gezonde leefomgeving en duurzame, circulaire economie.\nHet verkrijgen van het overzicht van deze mogelijke beleidsmaatregelen is de eerste stap.\nToegevoegde waarde van het planMER is om uit te dagen om verschillende en onderscheidende beleidsmaatregelen te formuleren voor de opgaven van het NMP.',
#  '• PBL integrale circulaire economie rapportage',
#  'Om de onafhankelijkheid en kwaliteit van het planMER NMP te borgen wordt een kwaliteitsteam ingezet op gerichte momenten gedurende het opstellen van het planMER.\nIn elk geval bij het vaststellen van de definitieve aanpak voor het planMER en na het opstellen van de concept beoordeling van de alternatieven.\nIn het kwaliteitsteam zitten onafhankelijke experts vanuit o.a. de planbureaus op de onderwerpen vitale ecosystemen, gezonde leefomgeving en duurzame, circulaire economie.',
#  'vitale ecosystemen, gezonde leefomgeving, en duurzame, circulaire economie.\nDeze hoofdopgaven worden uitgewerkt in operationele en/of uitvoeringsdoelen.\nOpgave Onderwerp waarop de ambitie bestaat om in het NMP (aanvullend)beleid op te nemen.',
#  '2050 zowel een 100% doelbereik van de Vogelen Habitatrichtlijn in Nederland, als een halvering van de ecologische voetafdruk.\nNMP erkent belang van biodiversiteit maar laat de plannen over aan Programma Versterken\nBiodiversiteit.\nDuurzame Mobiliteit Vermindering van verplaatsingen, verandering van vervoermiddel en vergroening van vervoermiddelen.\nIntegraal beleid tussen Bereikbaarheid, economie, gezondheid, leefmilieu en klimaat.\nNMP valt onder het leefmilieu.',
#  "Rijksbreed programma Circulaire Economie: 'Nederland circulair in 2050'",
#  'In de procedure van vaststelling van een (wijziging van het) bestemmingsplan is meestal een natuurtoets uitgevoerd.\nZo’n ecologisch onderzoek volstaat meestal om te kunnen beoordelen of de regels voor soortenbescherming van de Wet natuurbescherming aan de uitvoering van het plan in de weg staan.',
#  "• 36 aanwezige soorten niet kunnen terugvallen op een grootschaliger ecologisch systeem (zie hoofdstuk 2), waardoor ze geïsoleerd raken en alsnog op termijn niet kunnen overleven.\nEen tweede nadeel is het veelal ontbreken van juridisch afdwingbare normen voor natuurinclusief bouwen, waardoor het ook relatief makkelijk is dit 'duurzaamheidsonderdeel’ te schrappen mocht het bouwbudget ontoereikend blijken te zijn.",
#  'Er gaat veel tijd en geld om in de toepassing van de Wet natuurbescherming – bijvoorbeeld in ecologische onderzoeken, het achterhalen van lokale beleidskaders en overleg met het bevoegd gezag – maar dit vertaalt zich niet in versterking van de biodiversiteit.\nAls gevolg hiervan vertraagt de uitvoering van projecten.',
#  'Het is lastig complexe ecologische randvoorwaarden te vertalen naar in de uitvoering bruikbare en concrete adviezen (wat, wanneer, hoeveel, hoelang).',
#  'Het ontbreekt aan een goede onderbouwing van de economische waarde van natuurinclusief bouwen voor de biodiversiteit, de kwaliteit en leefbaarheid van de woonomgeving en de volksgezondheid.',
#  'Het in kaart brengen van de ‘staat van instandhouding’ zoals op grond van de wet Natuurbescherming gevraagd wordt voor een grote stad kost miljoenen.\nNog afgezien van de vraag of een stad dat kan betalen, zijn er waarschijnlijk onvoldoende ecologen om dat te doen.',
#  'Er is op dit moment een grotere vraag naar ecologen dan dat er aanbod is (capaciteitsgebrek en dus kennisgebrek).',
#  'Het ontbreekt voor veel maatregelen aan overeenstemming tussen ecologen onderling over de effecten daarvan op bescherming en instandhouding van soorten.',
#  'In de onderhandeling met bouwers en ontwikkelaars over niet juridisch afdwingbare duurzaamheidsambities, ontbreekt het de kleinere gemeenten vaak aan de specialismen (denk bijvoorbeeld aan ecologen, planeconomen) om voldoende professioneel tegenwicht te bieden.',
#  'Ecologen zijn vaak niet eenduidig in hun advies.\nSoms spreken ze elkaar zelfs tegen.\nAls dat gebeurt tijdens een bouwproject, leidt dat tot verwarring en frustratie en kost tijd en geld:',
#  '• Economische gevolgen',
#  'Plan van aanpak (bespreken met deskundige/ecoloog) met maatregelen zoals ‘werken buiten het broedseizoen’\nMaatregelen concretiseren bij aanvraag voor een bouwvergunning Curatief Werken volgens vastgestelde gedragscode 3.31 Wet natuurbescherming/11.4 5, 11.53, 11.59',
#  'Het SPAW-protocol is gericht op de bescherming van het mariene milieu in het Caribische zeegebied en bevat in het bijzonder regels over de bescherming van zeldzame en kwetsbare ecosystemen en habitats.',
#  'De GBA steunt op de pilaren van de eerste pijler: conditionaliteiten (de voorwaarden voor grondgebonden steun uit eerste en tweede pijler), ecoregelingen (eenjarige stimuleringsregeling) en tweede pijlerinterventies\nals het (meerjarige) Agrarisch Natuuren Landschapsbeheer (ANLb) en samenwerkingsprojecten.',
#  'Met een hogere conditionaliteit wordt het lastiger om boeren te verleiden om mee te doen aan ecoregelingen of ANLb, omdat die qua ambitieniveau immers verder moeten gaan dan de basisvoorwaarden van de conditionaliteit.\nHier speelt ook mee dat het over het algemeen effectiever is te belonen voor specifieke geleverde diensten, dan «one-size-fits-all» deelnemingsvoorwaarden op te leggen via de voorschriften van de conditionaliteit.\nTen algemene is de koers voor het NSP dan ook de conditionaliteiten laagdrempelig in te vullen, dicht bij de EU-voorschriften van de SPV.\nAndere dilemma’s hebben betrekking op de effectiviteit van ecoregelingen die in de eerste pijler zitten versus de tweedepijlerinterventies in generieke landsdekkende opgaven en in gebiedsspecifieke opgaven.\nDe eerstepijlermaatregelen moeten meer bijdragen aan generieke verduurzaming op het gebied van bodem, water en gewasbescherming, waarbij regionale accenten worden aangebracht.',
#  'Wanneer een landbouwer zich ertoe verbindt ten minste 7% van zijn bouwland te wijden aan niet-productieve oppervlakten en kenmerken, met inbegrip van braakliggende grond, dan kan daarvan het meerdere boven 3% via de ecoregeling kan worden vergoed.',
#  'staatssecretaris van Economische Zaken en Klimaat, D. Yeşilgöz-Zegerius - 13 december 2021',
#  'een sterkere VTH-uitvoering en effectievere aanpak van overtredingen2, heb ik uw Kamer toegezegd het Dreigingsbeeld milieucriminaliteit 2021 zo spoedig mogelijk na het openbaar worden toe te sturen.\nDit Dreigingsbeeld milieucriminaliteit is gemaakt in opdracht van de Strategische Milieukamer (SMK)3, de SMK stuurt op hoofdlijnen de strafrechtelijke aanpak van milieucriminaliteit aan.\nIn dit rapport zijn negen vormen van milieucriminaliteit geselecteerd die nader zijn uitgediept, variërend van dreigingen voor bodem en waterkwaliteit en biodiversiteit tot dreigingen gerelateerd aan de circulaire economie.',
#  'Zij begrepen dat in het EU-wetsvoorstel staat dat een dergelijke uitbreiding van het toepassingsgebied voorbarig zou zijn, vanwege de effectiviteit en handhaafbaarheid van de hierbij beoordeelde beleidsmaatregelen.\nIs de Minister bereid na te vragen bij de Europese Commissie op welke manier de handhaafbaarheid wordt bemoeilijkt voor de controlerende instanties door uitbreiding van de ecosystemen?',
#  'In programmalijn 3, Leefomgeving, natuur en biodiversiteit is opgenomen dat voor elk kansrijken ontwikkelgebied een ecosysteemen landschapsanalyse wordt gemaakt.\nDeze analyses vormen belangrijke bouwstenen voor de gebiedsprocessen.\nHiervoor wordt samen met de FMF op korte termijn een gebiedsanalyse waarbij de kansen voor koppeling met weidevogelaanpak',
#  'Onderwijs en werk\nbasis voor leven\nDe visie over Onderwijs en werk basis voor leven gaat uit van een meer open houding voor ieders talenten en dat eigenheid kansen biedt.\nVerder moet het principe van Meester-Gezel nieuw leven ingeblazen worden.\nDaarnaast is het belangrijk dat leren ook buiten het klaslokaal plaatsvindt, zogenaamde leer-ecosystemen kunnen daar bij helpen.',
#  'Er zouden leer-ecosystemen moeten komen:',
#  'Verzoek om de brief over de definities van ecosystemen m.b.t. de ontbossingsverordening, die de minister van LNV tijdens het commissiedebat van vorige week woensdag 16 februari beloofd had, vóór 8 maart met de Kamer te laten delen.',
#  'Sinds de inwerkingtreding van het Statuut in 2003 zijn zeven amendementsvoorstellen ter goedkeuring aan de Verdragspartijen voorgelegd.17\nIn geen van deze gevallen ging het om amendering ter uitbreiding van de vier bestaande categorieën internationale misdrijven uit het Statuut.\nNaar de mening van het kabinet is de internationale gemeenschap ver verwijderd van het bereiken van de benodigde consensus over de definitie en strafbaarstelling van ecocide als internationaal misdrijf.\nIllustratief hiervoor is het feit dat het in 1998 door de Raad van Europa gesloten Verdrag inzake de bescherming van het milieu door middel van strafrecht tot op heden door slechts één Staat (Estland) geratificeerd',
#  'Het kabinet deelt op veel punten de zorgen van de initiatiefnemer over de teruggang van biodiversiteit, aantasting van kwetsbare natuur en ecosystemen, en de effecten die dat heeft op mensen.\nDit kabinet ziet, ondanks de gedeelde zorg, het echter niet als het meest effectief om zich actief toe te leggen op een amendement bij het Statuut van Rome om een verbod op ecocide te bewerkstelligen.\nIn deze brief is uiteengezet welke redenen hiervoor bestaan.\nOok zijn, zonder de intentie te hebben hier compleet in te zijn geweest, enkele elementen uit het huidige beleid van het kabinet aangehaald om aan te geven welke instrumenten het kabinet wel als kansrijk ziet ter bescherming van kwetsbare ecosystemen en biodiversiteit.',
#  'rendement: economisch, ecologisch, sociaal en cultureel;\n• economisch duurzaam en verantwoord beheer.\nEen landgoedmodel leidt tot risicospreiding over een breder geheel dan een individuele boer, gemeente of waterschap, en betere mogelijkheden functies elkaar wederzijds te laten versterken.\nDit is een goed finan cierbare en al beproefde vorm van breder organiseren.',
#  'Dit betreft een aanvullende dekking die nodig is om de tarieven voor het bedrijfsleven met niet meer dan het CPB-indexcijfer, dat gebaseerd is op de macro economische verkenningen, te laten stijgen.\nHet bedrag ziet enerzijds op de demping van de gevolgen van integrale 25Tweede Kamer, vergaderjaar 2021–2022, 35 925 XIV, nr. 2',
#  'De Minister van LNV is verantwoordelijk voor het zorgdragen voor een in ecologisch, maatschappelijk en economisch opzicht verantwoord functio\xad nerende landen tuinbouw en voedselsector.\nHiertoe stelt de Minister regels op en creëert zij voorwaarden die het mogelijk maken om vermijdbaar verbruik van grondstoffen terug te dringen en om de natuurlijke leefom\xad geving en de natuurlijke hulpbronnen (waaronder dierenwelzijn) te verbeteren.',
#  'Alle standaarden stellen eisen aan het tegengaan van illegale ontbossing.\nDaarbij verbieden enkele standaarden, waaronder RTRS, ook legale ontbossing en het converteren van andere waardevolle ecosystemen.',
#  'Het is een doel, omdat we met kringlooplandbouw willen wég bewegen van de huidige nadruk op steeds hogere productie tegen een steeds lagere prijs.»5 Voor ondernemers die de omslag willen maken naar een vorm van landbouw die meerdere generaties houdbaar is, telt uiteindelijk de vraag of en hoe zij dit in bedrijfseconomisch opzicht voor elkaar kunnen krijgen.\nElke ondernemer weet dat verdere verduurzaming zowel nieuwe kansen biedt als financiële risico’s met zich mee kan brengen.\nVeel agrarisch ondernemers wíllen wel verder verduurzamen, maar ervaren weinig bewegingsruimte om echt andere keuzes te kunnen maken en zijn onzeker over de economische mogelijkheden.\nDat geeft hun onvoldoende houvast voor de toekomst en kan bij hen een zeker wantrouwen voeden jegens geluiden uit politiek, samenleving, ketenpartijen die aandringen op koersverandering.\nOm voldoende ondernemers mee te krijgen, moeten zij er dus op kunnen vertrouwen dat het kan lonen\nom wél te bewegen en risico’s te nemen.',
#  'mariene ecosystemen;',
#  'stedelijke ecosystemen;',
#  'Voor stedelijke ecosystemen is onder andere in de programmatische aanpak Groen in en om de stad[',
#  'Aanpassing instapeis ecoregeling in 2023',
#  'Uitvoeren van concrete projecten ecologisch beheer.',
#  'Bestaand thema: de gemeente is al meer dan tien jaar bezig met ecologisch bermbeheer.',
#  'ecologisch beheer',
#  'van het ontwikkelen tot mantelzoomvegetaties in bosplantsoen tot gefaseerd snoeien, van ecologisch 14 oeverbeheer tot kruidenrijke bermen.',
#  'verbindingen lanen sluiten voor vleermuizen of broeihopen voor ringslangen.\nVoor de meeste van de twaalf acties is ‘draagvlak’ onder bewoners aangekruist.\nOok is een aantal acties samen met de bewoners voorzien:\naanleg voedselbosjes en samenwerken in ecologisch bermbeheer.\nDe stand van zaken is in navolgende tabel te zien.\nAangegeven is welke acties al lopen en welke nog in de startfase zitten.',
#  'Evaluatie ecologisch bermbeheer door inwoners',
#  'Hiervan is een ecologische analyse gemaakt (rapport A&W).',
#  'Ecologisch bermbeheer X X X X Evaluatie/',
#  'VAN DE STAATSSECRETARIS VAN ECONOMISCHE ZAKEN EN KLIMAAT',
#  'De Staatssecretaris van Economische Zaken en Klimaat, D. Yeşilgöz-Zegerius kst-35092-28 ISSN',
#  'In opdracht van het Ministerie van Economische Zaken en Klimaat (EZK) wordt in het kader van Wozep (Wind op zee ecologisch programma) op dit moment een voorspellingsmodel voor massale vogeltrek ontwikkeld door de Universiteit van Amsterdam.\nDe planning is om begin 2023 een werkend vogelvoorspellingsmodel te hebben voor massale vogeltrek op rotorhoogte en een startstop-procedure.\nOp basis van het vogelvoorspellingsmodel zal de start-stop-procedure worden vormgegeven.\nDetectoren voor vleermuizen zijn bevestigd in de windparken in Luchterduinen, Prinses Amalia (PAWP) en op de TenneT-platforms van het net op zee in de windenergiegebieden Borssele en Hollandse Kust (zuid).\nMet deze detectoren kan in de komende jaren meer informatie worden verzameld over de vleermuistrek.\nDe start-stop-procedure voor vleermuizen is al geïmplementeerd en de criteria zijn middels een wijzigingsbesluit in alle tot dusverre genomen kavelbesluiten opgenomen.',
#  'Op 17 maart 2020 kondigde het kabinet het Noodpakket banen en economie aan.',
#  'Brief aan de Tweede Kamer over Noodpakket banen en economie.',
#  'Aanbiedingsbrief incidentele suppletoire begrotingen inzake noodpakket banen en economie van de minister van Financiën aan de Tweede Kamer.',
#  'Economisch Onderzoek.',
#  'Eindrapport Kust op Kracht: monitoring ecologische effecten 2.',
#  'Dat kan bijvoorbeeld door dassentunnels, eekhoornbruggen of ecoducten aan te leggen.\nMaar werken die faunavoorzieningen ook?\nDaarover gaan onder meer de projecten in dit hoofdstuk.',
#  '“Bij bouwprojecten nemen we natuur in de vorm van groene daken en gevels of nestkasten meteen mee.\nOok zijn we bezig met een ‘ecologische hoogstructuur’, een groene structuur van daken.',
#  'Ben Eenkhoorn (ecoloog van Hoogheemraadschap Hollands Noorderkwartier) is positief over de methode:',
#  'In augustus 2020 is het ambitiedocument Klimaat 2021\xad2025 voor de gemeenten Bergen, Uitgeest, Castricum en Heiloo vastgesteld.\nHet programma Klimaat geeft uitvoering aan de hierin vastgestelde doelen:\nBijdragen aan de CO2\xadreductiedoelstellingen uit het Klimaatakkoord (49% in 2030 t.o.v. 1990).\nDe leefomgeving klimaatbestendig in richten zoals omschreven is in het Deltaplan Ruimtelijke Adaptatie.\nToewerken naar een circulaire economie in 2050.',
#  'De pijlers circulaire economie, duurzame bedrijfsvoering, duurzame mobiliteit en energietransitie richten zich op het beperken van verdere klimaatverandering (mitigatie).\nHet reduceren van broeikasgassen door het treffen van mitigerende maatregelen is onvoldoende om de effecten van klimaatverandering tegen te gaan.\nDe pijler klimaatadaptatie richt zich daarom op het aanpassen van de leefomgeving én ons gedrag aan de effecten van klimaatverandering.\nOnder aanpassen van de leefomgeving verstaan we het bestendig maken tegen extreme regenval, droogte, hitte en overstromingen.\nOok het versterken van de biodiversiteit hoort hierbij.\nHet programma Klimaat bewerkstelligt in de gemeenten de omslag naar een klimaatadaptieve leefomgeving met een circulaire economie.\nWat er vooraf ging aan dit beleidsstuk Duurzame mobiliteit',
#  'Omslag naar een klimaatadaptieve leefomgeving met een circulaire economie',
#  'Duurzame bedrijfsvoering\nCirculaire economie\nKlimaatadaptatie',
#  'In het beleids\xad plan circulaire economie is hier aandacht voor.',
#  'BZK - Handreiking klimaatbestendige nieuwbouw, MRA - De Eindhovense Klimaattoets - Convenant Klimaatadaptief bouwen, Zuid-Holland\nORGANISATIE - Factsheet Duurzame rioolheffing - Economische verkenning klimaatadaptief bouwen (convenant) -',
#  'Wat de kansen zijn in het plangebied op basis van ecologische kennis;',
#  'Wat de ecologische samenhang is van de gekozen maatregelen voor gewenste soorten.',
#  'Om te komen tot een integrale ontwikkeling gaat het er om de ambitie vooraf te bepalen en te kijken naar de hoogst haalbare ecologische kwaliteit van het project.\nDoor biodiversiteit in het begin van het ontwerpproces te integreren kan een meerwaarde voor mens en natuur worden gerealiseerd.\nDaarom moet bij elk project en/of gebiedsontwikkeling een onderbouwing worden aangeleverd die toelicht op welke wijze de gekozen natuurinclusieve maatregelen worden toegepast in de projectontwikkeling en hoe de instandhouding wordt geborgd.',
#  'De lijst biedt vooralsnog het toetsingskader voor projecten.\nEventuele maatregelen die niet in de lijst zijn opgenomen zullen door een ecoloog of natuur\xadinclusieve specialist beoordeeld worden op ecologische bijdrage/ meerwaarde en kunnen aan de lijst worden toegevoegd.',
#  'Voor adequate inpassing van natuurinclusieve maatregelen is een ecologisch advies gewenst.\nHet gaat namelijk altijd om maatwerk en de juiste afweging van belangen.\nElk gebied heeft z’n eigen kenmerken en mogelijkheden.\nVoor huismussen, gierzwaluwen en vleermuizen zijn standaardvoorzieningen beschikbaar.\nMaar voor bijvoorbeeld een groen dak, groen als voedsel en beschutting of een nestkast voor een slechtvalk is maatwerk nodig.\nEcologische kennis is hierbij belangrijk.\nDit ecologisch onderzoek kan doorgaans efficiënt worden meegenomen bij de verplichte onderzoeken vanuit de Wet Natuurbescherming.',
#  'Ecologische wadi',
#  'Voor de beleidsdoorlichting is gebruik gemaakt van de beschikbare evaluaties van de beleidsplannen.\nIk verwijs u hiervoor verder naar de beleidsdoorlichting, met name de paragrafen 4.1 en 4.2 en de literatuurlijst in het rapport van SEO Economisch Onderzoek en Arcadis.',
#  'Nee, ik kan de verantwoordelijkheden en de effectiviteit van de centrale en decentrale overheden niet in een visualisatie weergeven.\nIk vind dat de verantwoordelijkheidsverdeling, met name in de relatie Rijk-provincies, in het rapport van SEO Economisch Onderzoek en Arcadis (met name de paragrafen 2.1.\nen 2.2.) goed is omschreven.\nOver de doeltreffendheid en doelmatigheid van het naar provincies gedelegeerde natuurbeleid en de besteding van de daarmee gemoeide middelen leggen gedeputeerde staten verantwoording af aan provinciale staten.\nOver de voortgang van de met de provincies overeengekomen afspraken in het kader van het Natuurpact (2013) rapporteren\nRijk en provincies gezamenlijk via de jaarlijkse Voortgangsrapportage Natuur.\nDe zevende, meest recente voortgangsrapportage is in november 2021 aan uw Kamer aangeboden (Kamerstuk 33 576, nr. 253).\n12 Kunt u toelichten waarom de beleidsdoorlichting pas in november 2021 is verschenen, terwijl deze zich richt op de periode 2015–2019?',
# ...
#  'Maar er is ook een ecologisch onderzoek van Bobbink in opdracht van Greenpeace, dat zegt dat veertien habitats op omvallen staan en het in 2025 echt voldoende gereduceerd moet zijn.\nIs dat ook een opdracht die wordt meegegeven aan de gebiedsgerichte processen?\nAls dat niet gebeurt, is dat juridisch dan niet heel erg kwetsbaar?\nKrijgen we dan niet weer een rechtszaak die de hele boel op de helling zet?\nEn welk klimaatdoel wordt meegegeven per gebied?\nIs dat een klimaatdoel voor 2030, of is dat ook een klimaatdoel voor 2040, zodat er ook terugberedeneerd kan worden?\nDe Minister heeft het over meekoppelkansen voor zoönosen, zoals al eerder is genoemd.\nWorden daar ook doelstellingen voor meegegeven?\nDan de ecologische autoriteit.\nWelke opdracht krijgt deze autoriteit en wie komen erin te zitten?\nWordt er gekeken naar de belangen van de mensen die daarin worden gezet?\nWat wordt er gedaan met de adviezen?\nWat voor financiële kaders krijgen ze mee?\nIk ben heel benieuwd naar de brief daarover en wil heel graag de toezegging dat we eerst een debat hebben voordat deze ecologische autoriteit in het leven wordt geroepen, want volgens mij is dit een cruciaal stukje van het coalitieakkoord, dat ons echt kan helpen om de politiek te disciplineren en te zorgen voor heel goed, consistent beleid.',
#  'Ja, ik had ze ook hiervoor bewaard, want dit is belangrijk.\nIk begrijp dat de afspraak is dat de natuur niet mag verslechteren.\nDie verplichting hebben wij.\nMaar stel nou dat je in een gebied zit langs de grens met Duitsland en dat uit de ecologische analyse komt dat de natuur goed is, maar dat de KDW wordt overschreden en dat we die nooit gaan halen omdat daar niks meer te halen is, want er zijn maar een paar extensieve boeren.\nKunnen we dan in die gebieden afwijken van de KDW?\nVallen die gebieden dan in die 26%?',
#  'Dat hangt af van de staat van de instandhouding van de natuur, want dat is gewoon een wettelijke verplichting.\nDat is de basis.\nMocht uit de ecologische analyse blijken dat er ruis zit tussen de staat van de instandhouding en de KDW, dat de situatie anders is, dan hebben we een ecologische autoriteit die daarnaar kan kijken.\nDat zou ik dan voorstellen, als die specifieke situatie zich voordoet, maar over de staat van instandhouding van de natuur is er die wettelijke bepaling.',
#  'We hebben ons helemaal suf onderzocht.\nWe hebben geen nieuwe wetenschappelijke onderzoeken nodig om hier echt gevalideerd iets van te kunnen zeggen.\nAs zo meteen de natuurdoelanalyses worden vastgeklikt, gebeurt dat door die onafhankelijke ecologische autoriteit.\nNogmaals, daar kom ik voor de zomer mee.\nIk heb al toegezegd graag in debat te gaan over hoe dat er precies uitziet.',
#  'Vraag 1 Erkent u dat de huidige stikstofcrisis – de «muur» waar het kabinet tegen aan is gereden – veroorzaakt is door politieke keuzes die (ook) in uw kabinetten zijn gemaakt, denk aan het afschaffen van de Ecologische Hoofdstructuur en de bezuiniging van 70% op het natuurbudget door het kabinet-Rutte I, het doorzetten van het toen al omstreden Programma Aanpak Stikstof (PAS) in het kabinet-Rutte II en een volstrekt ontoereikende stikstofwet in het kabinet-Rutte III?',
#  'De griffier voor dit verslag, De Boer BRIEF VAN DE VOORZITTERS VAN DE VASTE COMMISSIES VOOR ECONOMISCHE ZAKEN EN KLIMAAT / LANDBOUW, NATUUR EN VOEDSELKWALITEIT EN INFRASTRUCTUUR, WATERSTAAT EN OMGEVING',
#  'VAN DE MINISTER VAN ECONOMISCHE ZAKEN EN KLIMAAT',
#  'De Minister van Economische Zaken en Klimaat, M.A.M. Adriaansens BRIEF',
#  'Het versterken van de positie van de Nederlandse agro-, visserijen voedselketens, het stimuleren van groene economische groei en het bevorderen van transparantie en ketenverantwoordelijkheid in de Nederlandse agrovisserij- en voedselketens.',
#  'Stimuleren en faciliteren •\nHelpen realiseren van innovatieve combinaties tussen natuur en maatschappelijke en economische activiteiten.',
#  'De looptijd van 30 maanden is gebaseerd op de veronderstelling dat de economische levensduur van de Basisvoorzieningen die ontstaan zijn door de comparti\xad mentering van INSPECT, in lijn ligt met de oorspronkelijke economische levensduur van de tot en met 2019 geactiveerde onderdelen van INSPECT.\nTot slot is voor alle Basisvoorzieningen een inschatting gemaakt van het toekomstige gebruik.\nDe best mogelijke schatting van de waarde van de Basisvoorzieningen die hieruit voortvloeit is tenminste gelijk aan de bedrijfswaarde.\nVoor twee Basisvoorzieningen (Monstername en Bezwaar & Beroep) is ingeschat dat deze eind 2021 buiten gebruik gesteld zullen gaan worden.\nVoor deze twee Basisvoorzieningen is een bijzondere waardever\xad mindering (€ 0,9 mln., zijnde zes maanden afschrijvingskosten over 2022) toegepast.\nDe boekwaarde van de Basisvoorzieningen bedraagt € 13,5 mln. per 31 december 2020.',
#  'Economische informatievoorziening',
#  'Belangrijke conclusie in het rapport is dat het PAS niet effectief is geweest.\nHet PAS beoogde economische ontwikkeling samen te laten gaan met het op termijn realiseren van de doelen voor de Natura 2000-gebieden.\nDe conclusie luidt dat de daling van de stikstofdepositie als gevolg van ammoniakemissiere\xad ductie niet is gerealiseerd, waardoor de instandhoudingsdoelen van de Natura 2000-gebieden onverminderd onder druk staan.\nTegelijkertijd concluderen de onderzoekers dat het PAS ook goede elementen bevatte.\nOnderdelen van het PAS hebben volgens de onderzoekers goed gefunctio\xad neerd en kunnen meerwaarde hebben bij het ontwikkelen van nieuw stikstofbeleid.\nDe minister onderschrijft in de Kamerbrief de conclusies uit het rapport en neemt de aanbevelingen mee in de uitwerking van de structurele aanpak van de stikstofproblematiek.',
#  'Aanhangsel van de Handelingen\nVragen gesteld door de leden der Kamer, met de daarop door de regering gegeven antwoorden\n1163 Vragen van het lid Eerdmans (JA21) aan de Minister van Economische Zaken en Klimaat over het bericht «Achterlijke situaties bij glastuinders, eerste bedrijven stoppen»',
#  'De natuurlijke waarden van het groen zijn waardevol.\nDoor een gevarieerd en goed gekozen sortiment ontstaat een grote biodiversiteit.\nDit willen we bereiken door in een drietal pijlers te investeren:\nOntwikkelen van ecologische verbindingen - Inventariseren van fauna knelpunten om de ecologische verbindingen te optimaliseren\n- Toepassen van ecologisch beheer: gericht op verschillende doelsoorten met een gevarieerd assortiment',
#  'Biodiversiteit Ecologische structuur',
#  'variatie, verbinding, voedsel, verblijfplaatsen en veiligheid.\nOm de biodiversiteit te behouden moet de fauna op genoeg plekken voedsel kunnen vinden en is naast een grote verscheidenheid aan planten en bloemen ook hun spreiding en oppervlakte van belang.\nZe kunnen verbinding tussen groene plekken in een wijk of stad vormen en bieden veilige verblijfsplaatsen.\nIn het groenbeheer wordt hiermee rekening gehouden.\nDe gemeente Rhenen beschikt over relatief hoge natuurwaarden.\nEr is veel ecologisch groen aanwezig en het groen dat er is, is van nature soortenrijk, mede door de grote variatie in bodemsamenstelling.\nDaar tegenover zijn er veel stroken beplanting en grasstroken die weinig bijdragen aan de biodiversiteit.\nIn die stroken kan de biodiversiteit verbetert worden.',
#  'Realiseren van ecologische verbindingen (Lijnvormige)',
#  'groene elementen zo in inrichting en beheer aanpassen dat ze fungeren als ecologische verbinding.\nOmdat: Ecologische verbindingen bieden fauna de mogelijkheid om van het ene naar het andere (natuur)gebied te verplaatsen.\nEen natuurlijke inrichting draagt bij aan een hoge mate van biodiversiteit maar biedt ook een natuurlijke afweer tegen ziektes en plagen.',
#  'Ecologische verbindingen bepalen en locaties inrichten op te verwachten doelsoorten *in de bijlage is de ecologische structuurkaart opgenomen',
#  'Op de ecologische kaart zijn verschillende knelpunten aangewezen.\nOm de verbindingen optimaal in te richten en te beheren, bepalen we eerst welke doelsoorten we in de verschillende gebieden nastreven.\nHierbij is het provinciaal beleid een belangrijk vertrekpunt (immers, de natuur houdt zich niet aan gemeentegrenzen).\nMet deze doelsoorten kijken we vervolgens gericht hoe de knelpunten het beste opgelost kunnen worden.\nDaarnaast verkennen we binnen de kernen hoe de verschillende ‘groen snippers’ onderdeel uitmaken of kunnen uitmaken van een verbindingszone om zo de biodiversiteit te vergroten.\nOok de kleinere groene zones kunnen bijdragen aan de klimaatopgave door verkoeling en wateropname.',
#  'De eerste E geeft de waarde voor de economie aan.\nHiervoor is een rekenmodel ontwikkeld dat inzichtelijk maakt dat de baten van groen in veel gevallen groter zijn dan de kosten voor aanleg en onderhoud.\nDe tweede E staat voor de ecologische waarde van groen.\nDe waarde voor dieren en planten, maar ook voor de mens.\nDenk bijvoorbeeld aan de gewasbestuiving die nodig is voor de productie van voedsel.',
#  '- Wadi’s - Vaste planten - Bloemrijke bermen (ecologische berm en ruwe grasberm zijn nu in één meetlat samengevoegd) -\nWaterdoorlatende verharding - Boomkronen/snoeien solitaire straatbomen (schaduw)',
#  'De ecologische structuurkaart\nOp de ecologische structuurkaart zijn de grote ecologisch waardevolle gebieden aangewezen.',
#  '32 Ecologische structuurkaart',
#  'vermenigvuldigd met de periode dat een windpark meegaat.\nDaarnaast is een bedrag toegevoegd voor de gevolgen voor de visserijketen en visserijgemeenschappen.\nWageningen Research voert op verzoek van LNV een sociaaleconomische impactanalyse uit om de economische gevolgen van alle ontwikkelingen die op de visserij afkomen in kaart te brengen.\nOp basis hiervan zal bekeken worden welke aanvullende maatregelen getroffen kunnen worden.',
#  'Ik zal schema’s toevoegen aan het NSP zodat dat nog duidelijker te herleiden is.\nOok de toelichting hoe niet productieve investeringen die met het GLB-NSP gesubsidieerd worden wordt op dit punt verder verduidelijkt.\nDe leden van de D66-fractie merken op dat de Commissie ook meer interventies miste op het gebied van dierenwelzijn.\nIn de appreciatiebrief lijkt vooral de openstelling van de diergebonden ecoregeling hier de reactie op te zijn, alsmede de monitoringssystematiek.\nDenkt de Minister hiermee voldoende tegemoet te komen aan de kritiek van de Commissie, vooral aangezien het in het geval van de ecoregeling nog om een pilot gaat?\nWorden er aan de Commissie ook termijnen meegegeven over wanneer de diergebonden ecoregeling in werking zou moeten treden en zo ja, welke?',
#  'De in de vraagstelling gebruikte formulering «pappen en nathouden» deel ik niet.\nMet het nieuwe GLB, dat vanaf 1\xa0januari 2023 van kracht wordt, wordt juist ingezet om boeren te ondersteunen die zich inspannen de omslag naar een meer duurzame bedrijfsvoering te maken.\nEen omslag van meer generieke naar meer doelgerichte betalingen, zoals bijvoorbeeld de vergoedingen die voor boeren beschikbaar komen bij deelname aan de ecoregeling.\nVragen en opmerkingen van de leden van de SGP-, CUen BBB-fracties\nDe leden van de SGP-, CUen BBB-fracties constateren dat in de tweede praktijkproef meer dan de helft van de deelnemers aangaf dat ze niet deel kunnen of willen nemen aan de toen voorliggende ecoregeling.\nDeze leden maken zich daar zorgen over.\nOp welke wijze wil de Minister ervoor gaan zorgen dat meer agrarische ondernemers ook in 2023 mee gaan doen?\nDe Minister schrijft dat hij de puntentoekenning en de vergoeding van activiteiten in de ecoregeling wil actualiseren en optimaliseren.',
#  'Universiteit gevraagd om de score van activiteiten op doelstellingen in de eco-regelingen van het Nationaal Strategisch Plan nogmaals te beoordelen, met inachtneming van inbreng van zowel sectorals maatschappelijke organisaties.\nTevens heb een analyse gemaakt van de doorwerking van activiteiten op het perceel.\nDit heeft geleid tot een aanpassing van de puntentelling, zoals in de onderstaande tabel aangegeven:\nMet deze aanpassingen is het mijn opvatting dat de ecoregeling voor agrariërs haalbaar is.\nIk laat dit tevens nog doorrekenen op basis van de deelnemers van de praktijkproef.\nEen eerste inschatting is positief.\nDe leden van de SGP-, CUen BBB-fracties hebben eerder aandacht gevraagd voor de beperkte mogelijkheden voor akkerbouwers in de ecoregeling.\nDeze leden lezen dat de Minister pas in 2024 extra opties voor de akkerbouw (precisielandbouw, niet-kerende grondbewerking, biologische ongediertenbestrijding) in de ecoregeling wil opnemen.\nZij willen erop wijzen dat in het verslag van het tweede praktijkonderzoek wordt aangegeven dat het de vraag is of boeren die in 2023 afhaken bij de ecoregeling in 2024 en verder nog wel zullen deelnemen, omdat ze dan mogelijk kiezen voor intensivering en herhaaldelijk wijzigen van de bedrijfsvoering lastig is.\nDeelt de Minister deze zorg?',
#  'De provincie heeft twee belangrijke monitoringstrajecten om de weidevogelstand en de resultaten van het Actieplan Boerenlandvogels bij te houden:\n- Het weidevogelmeetnet wordt sinds 1990 gebruikt, daarbij wordt op een aantal vaste plots verspreid over de provincie de aantallen weidevogels bijgehouden.\nDit meetnet dient er vooral voor om zicht te houden op de provinciale trend van de weidevogels.\n- De beleidsmonitor weidevogels, daarbij worden drie representatieve gebieden in ZuidHolland elke 2-3 jaar gemonitord.\nHet gaat om Midden-Delfland, Haaglanden en de Krimpenerwaard.\nDe nu voorliggende resultaten zijn afkomstig uit de beleidsmonitor weidevogels.\nIn 2020 zijn weidevogels geïnventariseerd in de drie deelgebieden Midden-Delfland, Haaglanden en de Krimpenerwaard.\nDe inventarisatie volgt op een nulmeting in 2015 en een tweede inventarisatie in 2018 in de drie deelgebieden.\nBinnen deze tellingen wordt onderscheid gemaakt tussen een aantal beheertypen:',
#  'Om ecologisch (maai)beheer succesvol te laten zijn, is continuïteit van het maaibeheer van groot belang.\nDat lukt alleen als ook de bestuurders op de maaimachines gedegen kennis hebben van flora en fauna (soortenkennis en wetgeving), kennis hebben van de lokale situatie en hieraan willen bijdragen.\nDit geldt voor zowel de eigen medewerkers als voor de ingehuurde aannemers.',
#  'Principes ecologisch grasbeheer',
#  'Het basisprincipe van ecologisch beheer van grasvelden is het gras zo te beheren dat de inheemse flora en fauna zoveel mogelijk kansen krijgt.',
#  'Een locatie waar lang/bloemen kruidenrijke gras geen overlast veroorzaakt voor het gebruik als uitzichthoek, picknickplaats, hondenuitlaatstrook, verpacht, aangrenzend landgebruik (denk ook aan inspoeling van meststoffen).\n• Het kunnen creëren van gradiënten van nat naar droog of van zon naar schaduw.\nIn elke berm of grasveld kunnen we in principe, met een juist beheer, hogere natuurwaarden bereiken.\nDit vraagt dan soms wel om meer inspanningen.\nDoor het uitwerken van criteria, op basis waarvan we op een bepaalde locatie kiezen om ecologisch te gaan beheren, is het voor iedereen duidelijk waarom we een bepaalde maaimethode inzetten.',
#  'Hogere kosten (130% tot 175% t.o.v. huidig), kosten afvoeren van maaisel is prijsbepalend 4.\nAlle bermen die worden geklepeld maaien en zuigen met eco-maaikop (gemiddeld 2 keer per jaar)',
#  'De eigen dienst maait met een klepelmaaier een deel van het areaal op basis van jarenlange ervaring.\nMet andere een maaimachine (bv. investeren in een kleine maaizuigcombinatie) en extra instructies of opleiding kan ook meer ecologisch worden gemaaid.\n• Zoveel mogelijk aanpassingen meenemen in het bestek voor 2021 (verlenging).',
#  ...]
